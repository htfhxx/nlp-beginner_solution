# %%
'''
实验目的：实现基于CNN、RNN的文本分类

实验内容：
1）词嵌入初始化方式：随机embedding、word2vec、word2vec_fun-tured、加载glove
2）CNN/RNN的特征抽取
3）Dropout


参考：
https://arxiv.org/abs/1408.5882
https://github.com/yokusama/CNN_Sentence_Classification
https://torchtext.readthedocs.io/en/latest/
http://mlexplained.com/2018/02/08/a-comprehensive-tutorial-to-torchtext/

'''
# Out:
# '\n实验目的：实现基于CNN、RNN的文本分类\n\n实验内容：\n1）词嵌入初始化方式：随机embedding、word2vec、word2vec_fun-tured、加载glove\n2）CNN/RNN的特征抽取\n3）Dropout\n\n\n参考：\nhttps://arxiv.org/abs/1408.5882\nhttps://github.com/yokusama/CNN_Sentence_Classification\nhttps://torchtext.readthedocs.io/en/latest/\nhttp://mlexplained.com/2018/02/08/a-comprehensive-tutorial-to-torchtext/\n\n'

# %%
import os
import time
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import sklearn
print(os.getcwd())

dir_all_data='data\\task2_all_data.tsv'

BATCH_SIZE=10

cpu=True   #True   False 
if cpu :
    USE_CUDA = False
    DEVICE = torch.device('cpu')
else:
    USE_CUDA = torch.cuda.is_available()
    DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    torch.cuda.set_device(0)
# Out:
# D:\workspace\nlp_beginer_solution

# %%
#从文件中读取数据
data_all=pd.read_csv(dir_all_data,sep='\t')
#print(all_data.shape)    #(156060, 4)
#print(all_data.keys())   #['PhraseId', 'SentenceId', 'Phrase', 'Sentiment']
idx =np.arange(data_all.shape[0])
#print(data_all.head())
#print(type(idx))   #<class 'numpy.ndarray'>

# %%
#shuffle，划分验证集、测试集,并保存
seed=0
np.random.seed(seed)
#print(idx)
np.random.shuffle(idx)  
#print(idx)

train_size=int(len(idx) * 0.6)
test_size =int(len(idx) * 0.8)

data_all.iloc[idx[:train_size], :].to_csv('data/task2_train.csv',index=False)
data_all.iloc[idx[train_size:test_size], :].to_csv("data/task2_test.csv", index=False)
data_all.iloc[idx[test_size:], :].to_csv("data/task2_dev.csv", index=False)

# %%
#Torchtext采用声明式方法加载数据
from torchtext import data
PAD_TOKEN='<pad>'
TEXT = data.Field(sequential=True,batch_first=True, lower=True, pad_token=PAD_TOKEN)
LABEL = data.Field(sequential=False, batch_first=True, unk_token=None)

# %%
#读取数据

datafields = [("PhraseId", None), # 不需要的filed设置为None
              ("SentenceId", None),
              ('Phrase', TEXT),
              ('Sentiment', LABEL)]
train_data = data.TabularDataset(path='data/task2_train.csv', format='csv',
                                fields=datafields)
dev_data  = data.TabularDataset(path='data/task2_dev.csv', format='csv',
                                fields=datafields)
test_data = data.TabularDataset(path='data/task2_test.csv', format='csv',
                                fields=datafields)

# %%
print(len(train_data))
# Out:
# 93637

# %%
#构建词典，字符映射到embedding
TEXT.build_vocab(train_data,  vectors= 'glove.6B.50d',   #可以提前下载好
                 unk_init= lambda x:torch.nn.init.uniform_(x, a=-0.25, b=0.25))
LABEL.build_vocab(train_data)
PAD_INDEX = TEXT.vocab.stoi[PAD_TOKEN]
TEXT.vocab.vectors[PAD_INDEX] = 0.0

# %%
#得到词向量
pretrained_embeddings=TEXT.vocab.vectors
print(type(TEXT.vocab.vectors))
print(TEXT.vocab.vectors)
# Out:
# <class 'torch.Tensor'>
# tensor([[-0.1919, -0.2418,  0.0356,  ..., -0.1342, -0.1067,  0.1024],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.4180,  0.2497, -0.4124,  ..., -0.1841, -0.1151, -0.7858],
#         ...,
#         [ 0.2282,  0.0205, -0.4533,  ...,  0.5120,  1.0239, -0.8895],
#         [ 0.1172,  1.0841, -0.0531,  ..., -1.2205,  0.7453,  2.0112],
#         [ 0.1703,  0.3512,  1.5457,  ..., -0.4095, -0.4091,  0.5303]])

# %%
#构建迭代器
train_iterator = data.BucketIterator(train_data, batch_size=BATCH_SIZE, 
                                     train=True, shuffle=True,device=DEVICE)

dev_iterator = data.Iterator(dev_data, batch_size=len(dev_data), train=False,
                         sort=False, device=DEVICE)

test_iterator = data.Iterator(test_data, batch_size=len(test_data), train=False,
                          sort=False, device=DEVICE)

# %%
#部分参数设置
embedding_choice='rand'   #  'static'    'non-static'
num_embeddings = len(TEXT.vocab)
embedding_dim =50
dropout_p=0.5
filters_num=100

# %%
vocab_size=len(TEXT.vocab)
label_num=len(LABEL.vocab)
print(vocab_size,label_num)
# Out:
# 16473 6

# %%
import torch.nn.functional as F
class CNN(nn.Module):
    def __init__(self):
        super(CNN,self).__init__()
        self.embedding_choice=embedding_choice
        self.vocab_size=vocab_size
        
        if self.embedding_choice==  'rand':
            self.embedding=nn.Embedding(num_embeddings,embedding_dim)
            
        self.conv1 = nn.Conv2d(in_channels=1,out_channels=filters_num ,  #卷积产生的通道
                               kernel_size=(3, embedding_dim), padding=(2,0))
        
        self.conv2 = nn.Conv2d(in_channels=1,out_channels=filters_num ,  #卷积产生的通道
                               kernel_size=(4, embedding_dim), padding=(3,0))
        
        self.conv3 = nn.Conv2d(in_channels=1,out_channels=filters_num ,  #卷积产生的通道
                               kernel_size=(5, embedding_dim), padding=(4,0))
        
        self.dropout = nn.Dropout(dropout_p)
        
        self.fc = nn.Linear(filters_num * 3, label_num)
        
    def forward(self,x):      # (Batch_size, Length) 
        x=self.embedding(x).unsqueeze(1)      #(Batch_size, Length, Dimention) 
                                       #(Batch_size, 1, Length, Dimention) 
        
        x1 = F.relu(self.conv1(x)).squeeze(3)    #(Batch_size, filters_num, length+padding, 1) 
                                          #(Batch_size, filters_num, length+padding) 
        x1 = F.max_pool1d(x1, x1.size(2)).squeeze(2)  #(Batch_size, filters_num, 1)
                                               #(Batch_size, filters_num) 
         
        x2 = F.relu(self.conv2(x)).squeeze(3)  
        x2 = F.max_pool1d(x2, x2.size(2)).squeeze(2)      
        
        x3 = F.relu(self.conv3(x)).squeeze(3)  
        x3 = F.max_pool1d(x3, x3.size(2)).squeeze(2)      
        
        x = torch.cat((x1, x2, x3), dim=1)  #(Batch_size, filters_num *3 )
        x = self.dropout(x)      #(Batch_size, filters_num *3 )
        out = self.fc(x)       #(Batch_size, label_num  )
        return out

# %%
#构建模型

model=CNN()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)#创建优化器SGD
criterion = nn.CrossEntropyLoss()   #损失函数

if USE_CUDA:
    model.cuda()

# %%
import time
epoch=100
best_accuracy=0.0
start_time=time.time()

for i in range(epoch):
    model.train()
    total_loss=0.0
    accuracy=0.0
    total_correct=0.0
    total_data_num = len(train_iterator.dataset)
    steps = 0.0
    #训练
    for batch in train_iterator:
        steps+=1
        #print(steps)
        optimizer.zero_grad() #  梯度缓存清零
        
        batch_text=batch.Phrase
        batch_label=batch.Sentiment
        out=model(batch_text)    #[batch_size, label_num]
        loss = criterion(out, batch_label)
        total_loss = total_loss + loss.item() 

        loss.backward()
        optimizer.step()        

        correct = (torch.max(out, dim=1)[1]  #get the indices
                   .view(batch_label.size()) == batch_label).sum()
        total_correct = total_correct + correct.item()

        if steps%100==0:
            print("Epoch %d_%.3f%%:  Training average Loss: %f, Training accuracy: %f"
                      %(i, steps * train_iterator.batch_size*100/len(train_iterator.dataset),total_loss/steps, total_correct/total_data_num))  

    #验证
    model.eval()
    total_loss=0.0
    accuracy=0.0
    total_correct=0.0
    total_data_num = len(train_iterator.dataset)
    steps = 0.0    
    for batch in dev_iterator:
        steps+=1
        batch_text=batch.Phrase
        batch_label=batch.Sentiment
        out=model(batch_text)
        loss = criterion(out, batch_label)
        total_loss = total_loss + loss.item()
        
        correct = (torch.max(out, dim=1)[1].view(batch_label.size()) == batch_label).sum()
        total_correct = total_correct + correct.item()
        
        print("Epoch %d :  Verification average Loss: %f, Verification accuracy: %f%%,Total Time:%f"
          %(i, total_loss/steps, total_correct*100/total_data_num,time.time()-start_time))  
        
        if best_accuracy < total_correct/total_data_num :
            best_accuracy =total_correct/total_data_num 
            torch.save(model,'model_dict/epoch_%d_accuracy_%f'%(i,total_correct/total_data_num))
            print('Model is saved in model_dict/epoch_%d_accuracy_%f'%(i,total_correct/total_data_num))
            #torch.cuda.empty_cache()
# Out:
# Epoch 0_1.068%:  Training average Loss: 1.405351, Training accuracy: 0.004987
# Epoch 0_2.136%:  Training average Loss: 1.381584, Training accuracy: 0.009975
# Epoch 0_3.204%:  Training average Loss: 1.363787, Training accuracy: 0.014898
# Epoch 0_4.272%:  Training average Loss: 1.341407, Training accuracy: 0.020131
# Epoch 0_5.340%:  Training average Loss: 1.332115, Training accuracy: 0.025706
# Epoch 0_6.408%:  Training average Loss: 1.323313, Training accuracy: 0.030981
# Epoch 0_7.476%:  Training average Loss: 1.317740, Training accuracy: 0.036321
# Epoch 0_8.544%:  Training average Loss: 1.309630, Training accuracy: 0.041757
# Epoch 0_9.612%:  Training average Loss: 1.307138, Training accuracy: 0.047033
# Epoch 0_10.680%:  Training average Loss: 1.309347, Training accuracy: 0.052148
# Epoch 0_11.747%:  Training average Loss: 1.308197, Training accuracy: 0.057285
# Epoch 0_12.815%:  Training average Loss: 1.305253, Training accuracy: 0.062326
# Epoch 0_13.883%:  Training average Loss: 1.302527, Training accuracy: 0.067719
# Epoch 0_14.951%:  Training average Loss: 1.303031, Training accuracy: 0.072856
# Epoch 0_16.019%:  Training average Loss: 1.305494, Training accuracy: 0.077907
# Epoch 0_17.087%:  Training average Loss: 1.301893, Training accuracy: 0.083482
# Epoch 0_18.155%:  Training average Loss: 1.297926, Training accuracy: 0.088822
# Epoch 0_19.223%:  Training average Loss: 1.293667, Training accuracy: 0.094493
# Epoch 0_20.291%:  Training average Loss: 1.291911, Training accuracy: 0.099779
# Epoch 0_21.359%:  Training average Loss: 1.290798, Training accuracy: 0.105055
# Epoch 0_22.427%:  Training average Loss: 1.288380, Training accuracy: 0.110608
# Epoch 0_23.495%:  Training average Loss: 1.286252, Training accuracy: 0.116140
# Epoch 0_24.563%:  Training average Loss: 1.283194, Training accuracy: 0.121832
# Epoch 0_25.631%:  Training average Loss: 1.281199, Training accuracy: 0.127236
# Epoch 0_26.699%:  Training average Loss: 1.279212, Training accuracy: 0.132779
# Epoch 0_27.767%:  Training average Loss: 1.278449, Training accuracy: 0.138172
# Epoch 0_28.835%:  Training average Loss: 1.276947, Training accuracy: 0.143661
# Epoch 0_29.903%:  Training average Loss: 1.275279, Training accuracy: 0.149012
# Epoch 0_30.971%:  Training average Loss: 1.271830, Training accuracy: 0.154789
# Epoch 0_32.039%:  Training average Loss: 1.270139, Training accuracy: 0.160417
# Epoch 0_33.107%:  Training average Loss: 1.269098, Training accuracy: 0.165811
# Epoch 0_34.175%:  Training average Loss: 1.268425, Training accuracy: 0.171086
# Epoch 0_35.242%:  Training average Loss: 1.265327, Training accuracy: 0.177056
# Epoch 0_36.310%:  Training average Loss: 1.265885, Training accuracy: 0.182257
# Epoch 0_37.378%:  Training average Loss: 1.263276, Training accuracy: 0.188035
# Epoch 0_38.446%:  Training average Loss: 1.261595, Training accuracy: 0.193631
# Epoch 0_39.514%:  Training average Loss: 1.259862, Training accuracy: 0.199398
# Epoch 0_40.582%:  Training average Loss: 1.260286, Training accuracy: 0.204588
# Epoch 0_41.650%:  Training average Loss: 1.257958, Training accuracy: 0.210387
# Epoch 0_42.718%:  Training average Loss: 1.256337, Training accuracy: 0.216068
# Epoch 0_43.786%:  Training average Loss: 1.255463, Training accuracy: 0.221408
# Epoch 0_44.854%:  Training average Loss: 1.254929, Training accuracy: 0.226876
# Epoch 0_45.922%:  Training average Loss: 1.252548, Training accuracy: 0.232547
# Epoch 0_46.990%:  Training average Loss: 1.250828, Training accuracy: 0.238164
# Epoch 0_48.058%:  Training average Loss: 1.250092, Training accuracy: 0.243707
# Epoch 0_49.126%:  Training average Loss: 1.248772, Training accuracy: 0.249367
# Epoch 0_50.194%:  Training average Loss: 1.246594, Training accuracy: 0.255209
# Epoch 0_51.262%:  Training average Loss: 1.246181, Training accuracy: 0.260581
# Epoch 0_52.330%:  Training average Loss: 1.244251, Training accuracy: 0.266508
# Epoch 0_53.398%:  Training average Loss: 1.243418, Training accuracy: 0.272019
# Epoch 0_54.466%:  Training average Loss: 1.242646, Training accuracy: 0.277657
# Epoch 0_55.534%:  Training average Loss: 1.241456, Training accuracy: 0.283467
# Epoch 0_56.602%:  Training average Loss: 1.240206, Training accuracy: 0.289298
# Epoch 0_57.670%:  Training average Loss: 1.239532, Training accuracy: 0.294948
# Epoch 0_58.737%:  Training average Loss: 1.238214, Training accuracy: 0.300672
# Epoch 0_59.805%:  Training average Loss: 1.237622, Training accuracy: 0.306214
# Epoch 0_60.873%:  Training average Loss: 1.236638, Training accuracy: 0.312013
# Epoch 0_61.941%:  Training average Loss: 1.235752, Training accuracy: 0.317834
# Epoch 0_63.009%:  Training average Loss: 1.234534, Training accuracy: 0.323526
# Epoch 0_64.077%:  Training average Loss: 1.233208, Training accuracy: 0.329368
# Epoch 0_65.145%:  Training average Loss: 1.231996, Training accuracy: 0.335199
# Epoch 0_66.213%:  Training average Loss: 1.232063, Training accuracy: 0.340581
# Epoch 0_67.281%:  Training average Loss: 1.231447, Training accuracy: 0.346284
# Epoch 0_68.349%:  Training average Loss: 1.230357, Training accuracy: 0.352115
# Epoch 0_69.417%:  Training average Loss: 1.229710, Training accuracy: 0.357711
# Epoch 0_70.485%:  Training average Loss: 1.229257, Training accuracy: 0.363393
# Epoch 0_71.553%:  Training average Loss: 1.227618, Training accuracy: 0.369320
# Epoch 0_72.621%:  Training average Loss: 1.225905, Training accuracy: 0.375236
# Epoch 0_73.689%:  Training average Loss: 1.224677, Training accuracy: 0.381302
# Epoch 0_74.757%:  Training average Loss: 1.223621, Training accuracy: 0.387123
# Epoch 0_75.825%:  Training average Loss: 1.222217, Training accuracy: 0.393050
# Epoch 0_76.893%:  Training average Loss: 1.220686, Training accuracy: 0.399297
# Epoch 0_77.961%:  Training average Loss: 1.219718, Training accuracy: 0.405299
# Epoch 0_79.029%:  Training average Loss: 1.218955, Training accuracy: 0.410981
# Epoch 0_80.097%:  Training average Loss: 1.218020, Training accuracy: 0.416940
# Epoch 0_81.164%:  Training average Loss: 1.216038, Training accuracy: 0.423219
# Epoch 0_82.232%:  Training average Loss: 1.215131, Training accuracy: 0.429093
# Epoch 0_83.300%:  Training average Loss: 1.213537, Training accuracy: 0.435138
# Epoch 0_84.368%:  Training average Loss: 1.212283, Training accuracy: 0.441289
# Epoch 0_85.436%:  Training average Loss: 1.210806, Training accuracy: 0.447409
# Epoch 0_86.504%:  Training average Loss: 1.209579, Training accuracy: 0.453389
# Epoch 0_87.572%:  Training average Loss: 1.208697, Training accuracy: 0.459210
# Epoch 0_88.640%:  Training average Loss: 1.207680, Training accuracy: 0.465073
# Epoch 0_89.708%:  Training average Loss: 1.206855, Training accuracy: 0.470807
# Epoch 0_90.776%:  Training average Loss: 1.205603, Training accuracy: 0.476713
# Epoch 0_91.844%:  Training average Loss: 1.204694, Training accuracy: 0.482843
# Epoch 0_92.912%:  Training average Loss: 1.203650, Training accuracy: 0.488610
# Epoch 0_93.980%:  Training average Loss: 1.202237, Training accuracy: 0.494698
# Epoch 0_95.048%:  Training average Loss: 1.201153, Training accuracy: 0.500721
# Epoch 0_96.116%:  Training average Loss: 1.199725, Training accuracy: 0.506904
# Epoch 0_97.184%:  Training average Loss: 1.197996, Training accuracy: 0.513323
# Epoch 0_98.252%:  Training average Loss: 1.196543, Training accuracy: 0.519538
# Epoch 0_99.320%:  Training average Loss: 1.195275, Training accuracy: 0.525636
# Epoch 0 :  Verification average Loss: 1.031542, Verification accuracy: 19.486955%,Total Time:406.067032
# C:\Users\htfhxx\.conda\envs\python36\lib\site-packages\torch\serialization.py:256: UserWarning: Couldn't retrieve source code for container of type CNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Model is saved in model_dict/epoch_0_accuracy_0.194870
# Epoch 1_1.068%:  Training average Loss: 0.998286, Training accuracy: 0.006525
# Epoch 1_2.136%:  Training average Loss: 1.030809, Training accuracy: 0.012516
# Epoch 1_3.204%:  Training average Loss: 1.022446, Training accuracy: 0.019010
# Epoch 1_4.272%:  Training average Loss: 1.033006, Training accuracy: 0.025278
# Epoch 1_5.340%:  Training average Loss: 1.032399, Training accuracy: 0.031643
# Epoch 1_6.408%:  Training average Loss: 1.028389, Training accuracy: 0.038030
# Epoch 1_7.476%:  Training average Loss: 1.029686, Training accuracy: 0.044438
# Epoch 1_8.544%:  Training average Loss: 1.032250, Training accuracy: 0.050717
# Epoch 1_9.612%:  Training average Loss: 1.033162, Training accuracy: 0.057029
# Epoch 1_10.680%:  Training average Loss: 1.035210, Training accuracy: 0.063436
# Epoch 1_11.747%:  Training average Loss: 1.034795, Training accuracy: 0.069748
# Epoch 1_12.815%:  Training average Loss: 1.033592, Training accuracy: 0.076070
# Epoch 1_13.883%:  Training average Loss: 1.032106, Training accuracy: 0.082361
# Epoch 1_14.951%:  Training average Loss: 1.033945, Training accuracy: 0.088512
# Epoch 1_16.019%:  Training average Loss: 1.035883, Training accuracy: 0.094909
# Epoch 1_17.087%:  Training average Loss: 1.036461, Training accuracy: 0.100975
# Epoch 1_18.155%:  Training average Loss: 1.037231, Training accuracy: 0.107094
# Epoch 1_19.223%:  Training average Loss: 1.038801, Training accuracy: 0.113235
# Epoch 1_20.291%:  Training average Loss: 1.039716, Training accuracy: 0.119504
# Epoch 1_21.359%:  Training average Loss: 1.038146, Training accuracy: 0.126019
# Epoch 1_22.427%:  Training average Loss: 1.039813, Training accuracy: 0.132266
# Epoch 1_23.495%:  Training average Loss: 1.040175, Training accuracy: 0.138450
# Epoch 1_24.563%:  Training average Loss: 1.040538, Training accuracy: 0.144580
# Epoch 1_25.631%:  Training average Loss: 1.040326, Training accuracy: 0.150923
# Epoch 1_26.699%:  Training average Loss: 1.040488, Training accuracy: 0.157267
# Epoch 1_27.767%:  Training average Loss: 1.042735, Training accuracy: 0.163258
# Epoch 1_28.835%:  Training average Loss: 1.042812, Training accuracy: 0.169602
# Epoch 1_29.903%:  Training average Loss: 1.042004, Training accuracy: 0.175924
# Epoch 1_30.971%:  Training average Loss: 1.041965, Training accuracy: 0.182300
# Epoch 1_32.039%:  Training average Loss: 1.041206, Training accuracy: 0.188590
# Epoch 1_33.107%:  Training average Loss: 1.039720, Training accuracy: 0.194870
# Epoch 1_34.175%:  Training average Loss: 1.039965, Training accuracy: 0.201074
# Epoch 1_35.242%:  Training average Loss: 1.039749, Training accuracy: 0.207279
# Epoch 1_36.310%:  Training average Loss: 1.039239, Training accuracy: 0.213644
# Epoch 1_37.378%:  Training average Loss: 1.038973, Training accuracy: 0.219870
# Epoch 1_38.446%:  Training average Loss: 1.039267, Training accuracy: 0.226075
# Epoch 1_39.514%:  Training average Loss: 1.039248, Training accuracy: 0.232419
# Epoch 1_40.582%:  Training average Loss: 1.039477, Training accuracy: 0.238709
# Epoch 1_41.650%:  Training average Loss: 1.038789, Training accuracy: 0.245213
# Epoch 1_42.718%:  Training average Loss: 1.038450, Training accuracy: 0.251535
# Epoch 1_43.786%:  Training average Loss: 1.038368, Training accuracy: 0.257911
# Epoch 1_44.854%:  Training average Loss: 1.038182, Training accuracy: 0.264244
# Epoch 1_45.922%:  Training average Loss: 1.038063, Training accuracy: 0.270470
# Epoch 1_46.990%:  Training average Loss: 1.037012, Training accuracy: 0.277038
# Epoch 1_48.058%:  Training average Loss: 1.036778, Training accuracy: 0.283456
# Epoch 1_49.126%:  Training average Loss: 1.036281, Training accuracy: 0.289779
# Epoch 1_50.194%:  Training average Loss: 1.036364, Training accuracy: 0.295887
# Epoch 1_51.262%:  Training average Loss: 1.036068, Training accuracy: 0.302210
# Epoch 1_52.330%:  Training average Loss: 1.036000, Training accuracy: 0.308660
# Epoch 1_53.398%:  Training average Loss: 1.035344, Training accuracy: 0.315175
# Epoch 1_54.466%:  Training average Loss: 1.034784, Training accuracy: 0.321646
# Epoch 1_55.534%:  Training average Loss: 1.034464, Training accuracy: 0.328161
# Epoch 1_56.602%:  Training average Loss: 1.034479, Training accuracy: 0.334408
# Epoch 1_57.670%:  Training average Loss: 1.034562, Training accuracy: 0.340667
# Epoch 1_58.737%:  Training average Loss: 1.034278, Training accuracy: 0.347021
# Epoch 1_59.805%:  Training average Loss: 1.033994, Training accuracy: 0.353204
# Epoch 1_60.873%:  Training average Loss: 1.033918, Training accuracy: 0.359537
# Epoch 1_61.941%:  Training average Loss: 1.033648, Training accuracy: 0.365870
# Epoch 1_63.009%:  Training average Loss: 1.033534, Training accuracy: 0.372524
# Epoch 1_64.077%:  Training average Loss: 1.033877, Training accuracy: 0.378696
# Epoch 1_65.145%:  Training average Loss: 1.033801, Training accuracy: 0.385136
# Epoch 1_66.213%:  Training average Loss: 1.032903, Training accuracy: 0.391693
# Epoch 1_67.281%:  Training average Loss: 1.032978, Training accuracy: 0.398123
# Epoch 1_68.349%:  Training average Loss: 1.032369, Training accuracy: 0.404456
# Epoch 1_69.417%:  Training average Loss: 1.031842, Training accuracy: 0.411013
# Epoch 1_70.485%:  Training average Loss: 1.031178, Training accuracy: 0.417570
# Epoch 1_71.553%:  Training average Loss: 1.030795, Training accuracy: 0.424042
# Epoch 1_72.621%:  Training average Loss: 1.030731, Training accuracy: 0.430343
# Epoch 1_73.689%:  Training average Loss: 1.030391, Training accuracy: 0.436740
# Epoch 1_74.757%:  Training average Loss: 1.029830, Training accuracy: 0.443318
# Epoch 1_75.825%:  Training average Loss: 1.029551, Training accuracy: 0.449833
# Epoch 1_76.893%:  Training average Loss: 1.029556, Training accuracy: 0.455974
# Epoch 1_77.961%:  Training average Loss: 1.028566, Training accuracy: 0.462670
# Epoch 1_79.029%:  Training average Loss: 1.028140, Training accuracy: 0.468960
# Epoch 1_80.097%:  Training average Loss: 1.027987, Training accuracy: 0.475474
# Epoch 1_81.164%:  Training average Loss: 1.027604, Training accuracy: 0.482042
# Epoch 1_82.232%:  Training average Loss: 1.027440, Training accuracy: 0.488269
# Epoch 1_83.300%:  Training average Loss: 1.027357, Training accuracy: 0.494623
# Epoch 1_84.368%:  Training average Loss: 1.026967, Training accuracy: 0.501009
# Epoch 1_85.436%:  Training average Loss: 1.026599, Training accuracy: 0.507663
# Epoch 1_86.504%:  Training average Loss: 1.025572, Training accuracy: 0.514241
# Epoch 1_87.572%:  Training average Loss: 1.025869, Training accuracy: 0.520574
# Epoch 1_88.640%:  Training average Loss: 1.025415, Training accuracy: 0.527089
# Epoch 1_89.708%:  Training average Loss: 1.024514, Training accuracy: 0.533795
# Epoch 1_90.776%:  Training average Loss: 1.024406, Training accuracy: 0.539872
# Epoch 1_91.844%:  Training average Loss: 1.023970, Training accuracy: 0.546226
# Epoch 1_92.912%:  Training average Loss: 1.023679, Training accuracy: 0.552655
# Epoch 1_93.980%:  Training average Loss: 1.022816, Training accuracy: 0.559522
# Epoch 1_95.048%:  Training average Loss: 1.022590, Training accuracy: 0.565994
# Epoch 1_96.116%:  Training average Loss: 1.021472, Training accuracy: 0.572786
# Epoch 1_97.184%:  Training average Loss: 1.021202, Training accuracy: 0.579194
# Epoch 1_98.252%:  Training average Loss: 1.021187, Training accuracy: 0.585623
# Epoch 1_99.320%:  Training average Loss: 1.021046, Training accuracy: 0.591913
# Epoch 1 :  Verification average Loss: 0.955266, Verification accuracy: 20.562385%,Total Time:839.699128
# Model is saved in model_dict/epoch_1_accuracy_0.205624
# Epoch 2_1.068%:  Training average Loss: 0.919061, Training accuracy: 0.006920
# Epoch 2_2.136%:  Training average Loss: 0.931869, Training accuracy: 0.013531
# Epoch 2_3.204%:  Training average Loss: 0.926576, Training accuracy: 0.020248
# Epoch 2_4.272%:  Training average Loss: 0.929887, Training accuracy: 0.026870
# Epoch 2_5.340%:  Training average Loss: 0.937937, Training accuracy: 0.033352
# Epoch 2_6.408%:  Training average Loss: 0.939497, Training accuracy: 0.039941
# Epoch 2_7.476%:  Training average Loss: 0.937479, Training accuracy: 0.046766
# Epoch 2_8.544%:  Training average Loss: 0.938402, Training accuracy: 0.053334
# Epoch 2_9.612%:  Training average Loss: 0.936946, Training accuracy: 0.060094
# Epoch 2_10.680%:  Training average Loss: 0.930214, Training accuracy: 0.067057
# Epoch 2_11.747%:  Training average Loss: 0.929712, Training accuracy: 0.073689
# Epoch 2_12.815%:  Training average Loss: 0.931131, Training accuracy: 0.080289
# Epoch 2_13.883%:  Training average Loss: 0.926615, Training accuracy: 0.087348
# Epoch 2_14.951%:  Training average Loss: 0.927692, Training accuracy: 0.094023
# Epoch 2_16.019%:  Training average Loss: 0.927529, Training accuracy: 0.100804
# Epoch 2_17.087%:  Training average Loss: 0.926201, Training accuracy: 0.107746
# Epoch 2_18.155%:  Training average Loss: 0.927995, Training accuracy: 0.114335
# Epoch 2_19.223%:  Training average Loss: 0.929285, Training accuracy: 0.121074
# Epoch 2_20.291%:  Training average Loss: 0.930432, Training accuracy: 0.127695
# Epoch 2_21.359%:  Training average Loss: 0.930083, Training accuracy: 0.134455
# Epoch 2_22.427%:  Training average Loss: 0.929119, Training accuracy: 0.141130
# Epoch 2_23.495%:  Training average Loss: 0.931516, Training accuracy: 0.147730
# Epoch 2_24.563%:  Training average Loss: 0.930745, Training accuracy: 0.154490
# Epoch 2_25.631%:  Training average Loss: 0.929260, Training accuracy: 0.161389
# Epoch 2_26.699%:  Training average Loss: 0.929003, Training accuracy: 0.168139
# Epoch 2_27.767%:  Training average Loss: 0.928393, Training accuracy: 0.175006
# Epoch 2_28.835%:  Training average Loss: 0.930696, Training accuracy: 0.181552
# Epoch 2_29.903%:  Training average Loss: 0.931450, Training accuracy: 0.188067
# Epoch 2_30.971%:  Training average Loss: 0.930271, Training accuracy: 0.194891
# Epoch 2_32.039%:  Training average Loss: 0.931044, Training accuracy: 0.201811
# Epoch 2_33.107%:  Training average Loss: 0.930241, Training accuracy: 0.208497
# Epoch 2_34.175%:  Training average Loss: 0.930792, Training accuracy: 0.215460
# Epoch 2_35.242%:  Training average Loss: 0.930767, Training accuracy: 0.222348
# Epoch 2_36.310%:  Training average Loss: 0.930437, Training accuracy: 0.229012
# Epoch 2_37.378%:  Training average Loss: 0.930811, Training accuracy: 0.235580
# Epoch 2_38.446%:  Training average Loss: 0.931935, Training accuracy: 0.242148
# Epoch 2_39.514%:  Training average Loss: 0.932757, Training accuracy: 0.248748
# Epoch 2_40.582%:  Training average Loss: 0.933017, Training accuracy: 0.255294
# Epoch 2_41.650%:  Training average Loss: 0.934123, Training accuracy: 0.261681
# Epoch 2_42.718%:  Training average Loss: 0.933938, Training accuracy: 0.268580
# Epoch 2_43.786%:  Training average Loss: 0.934848, Training accuracy: 0.275190
# Epoch 2_44.854%:  Training average Loss: 0.934886, Training accuracy: 0.281801
# Epoch 2_45.922%:  Training average Loss: 0.934132, Training accuracy: 0.288583
# Epoch 2_46.990%:  Training average Loss: 0.934368, Training accuracy: 0.295332
# Epoch 2_48.058%:  Training average Loss: 0.935248, Training accuracy: 0.301889
# Epoch 2_49.126%:  Training average Loss: 0.934968, Training accuracy: 0.308564
# Epoch 2_50.194%:  Training average Loss: 0.933373, Training accuracy: 0.315698
# Epoch 2_51.262%:  Training average Loss: 0.934342, Training accuracy: 0.322266
# Epoch 2_52.330%:  Training average Loss: 0.934435, Training accuracy: 0.329037
# Epoch 2_53.398%:  Training average Loss: 0.933804, Training accuracy: 0.335904
# Epoch 2_54.466%:  Training average Loss: 0.933175, Training accuracy: 0.342749
# Epoch 2_55.534%:  Training average Loss: 0.933139, Training accuracy: 0.349691
# Epoch 2_56.602%:  Training average Loss: 0.934210, Training accuracy: 0.356195
# Epoch 2_57.670%:  Training average Loss: 0.933301, Training accuracy: 0.363083
# Epoch 2_58.737%:  Training average Loss: 0.933416, Training accuracy: 0.369672
# Epoch 2_59.805%:  Training average Loss: 0.932773, Training accuracy: 0.376539
# Epoch 2_60.873%:  Training average Loss: 0.932469, Training accuracy: 0.383235
# Epoch 2_61.941%:  Training average Loss: 0.932769, Training accuracy: 0.389963
# Epoch 2_63.009%:  Training average Loss: 0.932987, Training accuracy: 0.396681
# Epoch 2_64.077%:  Training average Loss: 0.933311, Training accuracy: 0.403409
# Epoch 2_65.145%:  Training average Loss: 0.933135, Training accuracy: 0.410020
# Epoch 2_66.213%:  Training average Loss: 0.932785, Training accuracy: 0.416865
# Epoch 2_67.281%:  Training average Loss: 0.932608, Training accuracy: 0.423572
# Epoch 2_68.349%:  Training average Loss: 0.932581, Training accuracy: 0.430279
# Epoch 2_69.417%:  Training average Loss: 0.932119, Training accuracy: 0.437017
# Epoch 2_70.485%:  Training average Loss: 0.932688, Training accuracy: 0.443681
# Epoch 2_71.553%:  Training average Loss: 0.932423, Training accuracy: 0.450645
# Epoch 2_72.621%:  Training average Loss: 0.932564, Training accuracy: 0.457191
# Epoch 2_73.689%:  Training average Loss: 0.932653, Training accuracy: 0.463844
# Epoch 2_74.757%:  Training average Loss: 0.933489, Training accuracy: 0.470295
# Epoch 2_75.825%:  Training average Loss: 0.933667, Training accuracy: 0.476991
# Epoch 2_76.893%:  Training average Loss: 0.933497, Training accuracy: 0.483804
# Epoch 2_77.961%:  Training average Loss: 0.933508, Training accuracy: 0.490383
# Epoch 2_79.029%:  Training average Loss: 0.933553, Training accuracy: 0.497004
# Epoch 2_80.097%:  Training average Loss: 0.932764, Training accuracy: 0.504032
# Epoch 2_81.164%:  Training average Loss: 0.931792, Training accuracy: 0.510920
# Epoch 2_82.232%:  Training average Loss: 0.931164, Training accuracy: 0.517947
# Epoch 2_83.300%:  Training average Loss: 0.930975, Training accuracy: 0.524782
# Epoch 2_84.368%:  Training average Loss: 0.931058, Training accuracy: 0.531681
# Epoch 2_85.436%:  Training average Loss: 0.931089, Training accuracy: 0.538334
# Epoch 2_86.504%:  Training average Loss: 0.931193, Training accuracy: 0.545073
# Epoch 2_87.572%:  Training average Loss: 0.930725, Training accuracy: 0.552218
# Epoch 2_88.640%:  Training average Loss: 0.930470, Training accuracy: 0.559053
# Epoch 2_89.708%:  Training average Loss: 0.930511, Training accuracy: 0.565717
# Epoch 2_90.776%:  Training average Loss: 0.930247, Training accuracy: 0.572594
# Epoch 2_91.844%:  Training average Loss: 0.930726, Training accuracy: 0.579045
# Epoch 2_92.912%:  Training average Loss: 0.930476, Training accuracy: 0.585805
# Epoch 2_93.980%:  Training average Loss: 0.931055, Training accuracy: 0.592383
# Epoch 2_95.048%:  Training average Loss: 0.930356, Training accuracy: 0.599464
# Epoch 2_96.116%:  Training average Loss: 0.930520, Training accuracy: 0.605989
# Epoch 2_97.184%:  Training average Loss: 0.930762, Training accuracy: 0.612685
# Epoch 2_98.252%:  Training average Loss: 0.930590, Training accuracy: 0.619381
# Epoch 2_99.320%:  Training average Loss: 0.931065, Training accuracy: 0.625896
# Epoch 2 :  Verification average Loss: 0.933980, Verification accuracy: 21.147623%,Total Time:1273.271778
# Model is saved in model_dict/epoch_2_accuracy_0.211476
# Epoch 3_1.068%:  Training average Loss: 0.904716, Training accuracy: 0.006888
# Epoch 3_2.136%:  Training average Loss: 0.874192, Training accuracy: 0.013873
# Epoch 3_3.204%:  Training average Loss: 0.874252, Training accuracy: 0.020761
# Epoch 3_4.272%:  Training average Loss: 0.872508, Training accuracy: 0.027639
# Epoch 3_5.340%:  Training average Loss: 0.866609, Training accuracy: 0.034751
# Epoch 3_6.408%:  Training average Loss: 0.864199, Training accuracy: 0.041864
# Epoch 3_7.476%:  Training average Loss: 0.859175, Training accuracy: 0.049147
# Epoch 3_8.544%:  Training average Loss: 0.857055, Training accuracy: 0.056004
# Epoch 3_9.612%:  Training average Loss: 0.855001, Training accuracy: 0.063137
# Epoch 3_10.680%:  Training average Loss: 0.856670, Training accuracy: 0.070197
# Epoch 3_11.747%:  Training average Loss: 0.858529, Training accuracy: 0.077117
# Epoch 3_12.815%:  Training average Loss: 0.859758, Training accuracy: 0.084048
# Epoch 3_13.883%:  Training average Loss: 0.859080, Training accuracy: 0.091086
# Epoch 3_14.951%:  Training average Loss: 0.863536, Training accuracy: 0.097803
# Epoch 3_16.019%:  Training average Loss: 0.864558, Training accuracy: 0.104563
# Epoch 3_17.087%:  Training average Loss: 0.867050, Training accuracy: 0.111238
# Epoch 3_18.155%:  Training average Loss: 0.863564, Training accuracy: 0.118564
# Epoch 3_19.223%:  Training average Loss: 0.861860, Training accuracy: 0.125730
# Epoch 3_20.291%:  Training average Loss: 0.860101, Training accuracy: 0.132800

# %%
#测试
PATH='model_dict/epoch_6_accuracy_0.213879'
model = torch.load(PATH)

total_loss=0.0
accuracy=0.0
total_correct=0.0
total_data_num = len(train_iterator.dataset)
steps = 0.0    
start_time=time.time()
for batch in test_iterator:
    steps+=1
    batch_text=batch.Phrase
    batch_label=batch.Sentiment
    out=model(batch_text)
    loss = criterion(out, batch_label)
    total_loss = total_loss + loss.item()

    correct = (torch.max(out, dim=1)[1].view(batch_label.size()) == batch_label).sum()
    total_correct = total_correct + correct.item()

print("Test average Loss: %f, Test accuracy: %f，Total time: %f"
  %(total_loss/steps, total_correct/total_data_num,time.time()-start_time) )
# Out:
# Test average Loss: 0.942344, Test accuracy: 0.212843，Total time: 16.872462
