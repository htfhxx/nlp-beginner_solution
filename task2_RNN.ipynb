# %%
'''
实验目的：实现基于RNN的文本分类

实验内容：
1）词嵌入初始化方式：随机embedding、加载glove
2）CNN/RNN的特征抽取
3）Dropout


参考：
https://arxiv.org/abs/1408.5882
https://github.com/yokusama/CNN_Sentence_Classification
https://torchtext.readthedocs.io/en/latest/
http://mlexplained.com/2018/02/08/a-comprehensive-tutorial-to-torchtext/
https://machinelearningmastery.com/sequence-classification-lstm-recurrent-neural-networks-python-keras/


https://github.com/yunjey/pytorch-tutorial/blob/master/tutorials/02-intermediate/bidirectional_recurrent_neural_network/main.py#L39-L58

'''

# %%
import os
import time
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import sklearn
print(os.getcwd())

dir_all_data='data\\task2_all_data.tsv'

BATCH_SIZE=10

cpu=True   #True   False 
if cpu :
    USE_CUDA = False
    DEVICE = torch.device('cpu')
else:
    USE_CUDA = torch.cuda.is_available()
    DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    torch.cuda.set_device(0)
# Out:
# D:\workspace\nlp_beginer_solution

# %%
#从文件中读取数据
data_all=pd.read_csv(dir_all_data,sep='\t')
#print(all_data.shape)    #(156060, 4)
#print(all_data.keys())   #['PhraseId', 'SentenceId', 'Phrase', 'Sentiment']
idx =np.arange(data_all.shape[0])
#print(data_all.head())
#print(type(idx))   #<class 'numpy.ndarray'>

# %%
#shuffle，划分验证集、测试集,并保存
seed=0
np.random.seed(seed)
#print(idx)
np.random.shuffle(idx)  
#print(idx)

train_size=int(len(idx) * 0.6)
test_size =int(len(idx) * 0.8)

data_all.iloc[idx[:train_size], :].to_csv('data/task2_train.csv',index=False)
data_all.iloc[idx[train_size:test_size], :].to_csv("data/task2_test.csv", index=False)
data_all.iloc[idx[test_size:], :].to_csv("data/task2_dev.csv", index=False)

# %%
#Torchtext采用声明式方法加载数据
from torchtext import data
PAD_TOKEN='<pad>'
TEXT = data.Field(sequential=True,batch_first=True, lower=True, pad_token=PAD_TOKEN)
LABEL = data.Field(sequential=False, batch_first=True, unk_token=None)

# %%
#读取数据

datafields = [("PhraseId", None), # 不需要的filed设置为None
              ("SentenceId", None),
              ('Phrase', TEXT),
              ('Sentiment', LABEL)]
train_data = data.TabularDataset(path='data/task2_train.csv', format='csv',
                                fields=datafields)
dev_data  = data.TabularDataset(path='data/task2_dev.csv', format='csv',
                                fields=datafields)
test_data = data.TabularDataset(path='data/task2_test.csv', format='csv',
                                fields=datafields)

# %%
print(len(train_data))
# Out:
# 93637

# %%
#构建词典，字符映射到embedding
TEXT.build_vocab(train_data,  vectors= 'glove.6B.50d',   #可以提前下载好
                 unk_init= lambda x:torch.nn.init.uniform_(x, a=-0.25, b=0.25))
LABEL.build_vocab(train_data)

#得到索引，PAD_TOKEN='<pad>'
PAD_INDEX = TEXT.vocab.stoi[PAD_TOKEN]
TEXT.vocab.vectors[PAD_INDEX] = 0.0

# %%
#得到词向量
#pretrained_embeddings=TEXT.vocab.vectors
#print(type(TEXT.vocab.vectors))
#print(TEXT.vocab.vectors)

# %%
#构建迭代器
train_iterator = data.BucketIterator(train_data, batch_size=BATCH_SIZE, 
                                     train=True, shuffle=True,device=DEVICE)

dev_iterator = data.Iterator(dev_data, batch_size=len(dev_data), train=False,
                         sort=False, device=DEVICE)

test_iterator = data.Iterator(test_data, batch_size=len(test_data), train=False,
                          sort=False, device=DEVICE)

# %%
#部分参数设置
embedding_choice='glove'   #  'static'    'non-static'
num_embeddings = len(TEXT.vocab)
embedding_dim =50
dropout_p=0.5

vocab_size=len(TEXT.vocab)
label_num=len(LABEL.vocab)
print(vocab_size,label_num)

hidden_size=20  #隐藏单元数
num_layers=1  #层数
# Out:
# 16473 6

# %%
from torch import nn
class LSTM(nn.Module):
    def __init__(self):
        super(LSTM,self).__init__()
        
        self.embedding_choice=embedding_choice        
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        
        if self.embedding_choice==  'rand':
            self.embedding=nn.Embedding(num_embeddings,embedding_dim)
        if self.embedding_choice==  'glove':
            self.embedding = nn.Embedding(num_embeddings, embedding_dim, 
                padding_idx=PAD_INDEX).from_pretrained(TEXT.vocab.vectors, freeze=True)
        #input_size (输入的特征维度),hidden_size ,num_layers 
        self.lstm = nn.LSTM(embedding_dim, hidden_size, num_layers, batch_first=True,bidirectional=True)
        self.dropout = nn.Dropout(dropout_p)    
        self.fc = nn.Linear(hidden_size * 2, label_num)  # 2 for bidirection
        
        
        
    def forward(self,x):      # (Batch_size, Length) 
        # Set initial hidden and cell states 
        # h_n (num_layers * num_directions, batch, hidden_size)
        h0 = torch.zeros(self.num_layers * 2, x.size(0), self.hidden_size)
        # c_n (num_layers * num_directions, batch, hidden_size): 
        c0 = torch.zeros(self.num_layers * 2, x.size(0), self.hidden_size)
        
        if USE_CUDA:
            h0=h0.cuda()
            c0=c0.cuda()
        
        x=self.embedding(x)     #(Batch_size, Length) 
                                       #(Batch_size,  Length, Dimention) 
        
        out, _ = self.lstm(x, (h0, c0))   #(Batch_size, Length，Dimention) 
                                        # (batch_size, Length, hidden_size)  
        out=self.dropout(out)
        
        out = self.fc(out[:, -1, :])   # (batch_size, Length, hidden_size)  
                                        # (batch_size, label_num)  
        return out

# %%
#构建模型

model=LSTM()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)#创建优化器SGD
criterion = nn.CrossEntropyLoss()   #损失函数

if USE_CUDA:
    model.cuda()

# %%
import time
epoch=100
best_accuracy=0.0
start_time=time.time()

for i in range(epoch):
    model.train()
    total_loss=0.0
    accuracy=0.0
    total_correct=0.0
    total_data_num = len(train_iterator.dataset)
    steps = 0.0
    #训练
    for batch in train_iterator:
        steps+=1
        #print(steps)
        optimizer.zero_grad() #  梯度缓存清零
        
        batch_text=batch.Phrase
        batch_label=batch.Sentiment
        out=model(batch_text)    #[batch_size, label_num]
        loss = criterion(out, batch_label)
        total_loss = total_loss + loss.item() 

        loss.backward()
        optimizer.step()        

        correct = (torch.max(out, dim=1)[1]  #get the indices
                   .view(batch_label.size()) == batch_label).sum()
        total_correct = total_correct + correct.item()

        if steps%100==0:
            print("Epoch %d_%.3f%%:  Training average Loss: %f, Training accuracy: %f"
                      %(i, steps * train_iterator.batch_size*100/len(train_iterator.dataset),total_loss/steps, total_correct/total_data_num))  

    #验证
    model.eval()
    total_loss=0.0
    accuracy=0.0
    total_correct=0.0
    total_data_num = len(train_iterator.dataset)
    steps = 0.0    
    for batch in dev_iterator:
        steps+=1
        batch_text=batch.Phrase
        batch_label=batch.Sentiment
        out=model(batch_text)
        loss = criterion(out, batch_label)
        total_loss = total_loss + loss.item()
        
        correct = (torch.max(out, dim=1)[1].view(batch_label.size()) == batch_label).sum()
        total_correct = total_correct + correct.item()
        
        print("Epoch %d :  Verification average Loss: %f, Verification accuracy: %f%%,Total Time:%f"
          %(i, total_loss/steps, total_correct*100/total_data_num,time.time()-start_time))  
        
        if best_accuracy < total_correct/total_data_num :
            best_accuracy =total_correct/total_data_num 
            torch.save(model,'model_dict/model_lstm/epoch_%d_accuracy_%f'%(i,total_correct/total_data_num))
            print('Model is saved in model_dict/model_lstm/epoch_%d_accuracy_%f'%(i,total_correct/total_data_num))
            #torch.cuda.empty_cache()
# Out:
# Epoch 0_1.068%:  Training average Loss: 1.217845, Training accuracy: 0.005372
# Epoch 0_2.136%:  Training average Loss: 1.207918, Training accuracy: 0.010744
# Epoch 0_3.204%:  Training average Loss: 1.196013, Training accuracy: 0.016511
# Epoch 0_4.272%:  Training average Loss: 1.199137, Training accuracy: 0.022149
# Epoch 0_5.340%:  Training average Loss: 1.191290, Training accuracy: 0.028066
# Epoch 0_6.408%:  Training average Loss: 1.203007, Training accuracy: 0.033555
# Epoch 0_7.476%:  Training average Loss: 1.209848, Training accuracy: 0.039141
# Epoch 0_8.544%:  Training average Loss: 1.212190, Training accuracy: 0.044566
# Epoch 0_9.612%:  Training average Loss: 1.214535, Training accuracy: 0.050194
# Epoch 0_10.680%:  Training average Loss: 1.211269, Training accuracy: 0.055843
# Epoch 0_11.747%:  Training average Loss: 1.210257, Training accuracy: 0.061482
# Epoch 0_12.815%:  Training average Loss: 1.209050, Training accuracy: 0.067132
# Epoch 0_13.883%:  Training average Loss: 1.202895, Training accuracy: 0.073059
# Epoch 0_14.951%:  Training average Loss: 1.203442, Training accuracy: 0.078644
# Epoch 0_16.019%:  Training average Loss: 1.202789, Training accuracy: 0.084294
# Epoch 0_17.087%:  Training average Loss: 1.203174, Training accuracy: 0.089911
# Epoch 0_18.155%:  Training average Loss: 1.203223, Training accuracy: 0.095432
# Epoch 0_19.223%:  Training average Loss: 1.202509, Training accuracy: 0.101167
# Epoch 0_20.291%:  Training average Loss: 1.202553, Training accuracy: 0.106646
# Epoch 0_21.359%:  Training average Loss: 1.199738, Training accuracy: 0.112530
# Epoch 0_22.427%:  Training average Loss: 1.198889, Training accuracy: 0.118126
# Epoch 0_23.495%:  Training average Loss: 1.197964, Training accuracy: 0.123722
# Epoch 0_24.563%:  Training average Loss: 1.197253, Training accuracy: 0.129329
# Epoch 0_25.631%:  Training average Loss: 1.196395, Training accuracy: 0.134979
# Epoch 0_26.699%:  Training average Loss: 1.195058, Training accuracy: 0.140703
# Epoch 0_27.767%:  Training average Loss: 1.195033, Training accuracy: 0.146267
# Epoch 0_28.835%:  Training average Loss: 1.194071, Training accuracy: 0.151948
# Epoch 0_29.903%:  Training average Loss: 1.193713, Training accuracy: 0.157395
# Epoch 0_30.971%:  Training average Loss: 1.194013, Training accuracy: 0.162927
# Epoch 0_32.039%:  Training average Loss: 1.194456, Training accuracy: 0.168224
# Epoch 0_33.107%:  Training average Loss: 1.193158, Training accuracy: 0.173916
# Epoch 0_34.175%:  Training average Loss: 1.192141, Training accuracy: 0.179470
# Epoch 0_35.242%:  Training average Loss: 1.191465, Training accuracy: 0.185055
# Epoch 0_36.310%:  Training average Loss: 1.189868, Training accuracy: 0.191057
# Epoch 0_37.378%:  Training average Loss: 1.189535, Training accuracy: 0.196792
# Epoch 0_38.446%:  Training average Loss: 1.188978, Training accuracy: 0.202484
# Epoch 0_39.514%:  Training average Loss: 1.187510, Training accuracy: 0.208272
# Epoch 0_40.582%:  Training average Loss: 1.187704, Training accuracy: 0.213933
# Epoch 0_41.650%:  Training average Loss: 1.186220, Training accuracy: 0.219870
# Epoch 0_42.718%:  Training average Loss: 1.185325, Training accuracy: 0.225691
# Epoch 0_43.786%:  Training average Loss: 1.184303, Training accuracy: 0.231436
# Epoch 0_44.854%:  Training average Loss: 1.183922, Training accuracy: 0.237161
# Epoch 0_45.922%:  Training average Loss: 1.183102, Training accuracy: 0.242831
# Epoch 0_46.990%:  Training average Loss: 1.182641, Training accuracy: 0.248534
# Epoch 0_48.058%:  Training average Loss: 1.183103, Training accuracy: 0.254034
# Epoch 0_49.126%:  Training average Loss: 1.183038, Training accuracy: 0.259726
# Epoch 0_50.194%:  Training average Loss: 1.182546, Training accuracy: 0.265365
# Epoch 0_51.262%:  Training average Loss: 1.181830, Training accuracy: 0.271335
# Epoch 0_52.330%:  Training average Loss: 1.181894, Training accuracy: 0.276963
# Epoch 0_53.398%:  Training average Loss: 1.181039, Training accuracy: 0.283029
# Epoch 0_54.466%:  Training average Loss: 1.180097, Training accuracy: 0.289052
# Epoch 0_55.534%:  Training average Loss: 1.180097, Training accuracy: 0.294595
# Epoch 0_56.602%:  Training average Loss: 1.178814, Training accuracy: 0.300864
# Epoch 0_57.670%:  Training average Loss: 1.179177, Training accuracy: 0.306439
# Epoch 0_58.737%:  Training average Loss: 1.177629, Training accuracy: 0.312515
# Epoch 0_59.805%:  Training average Loss: 1.176543, Training accuracy: 0.318517
# Epoch 0_60.873%:  Training average Loss: 1.176134, Training accuracy: 0.324284
# Epoch 0_61.941%:  Training average Loss: 1.174411, Training accuracy: 0.330446
# Epoch 0_63.009%:  Training average Loss: 1.173145, Training accuracy: 0.336363
# Epoch 0_64.077%:  Training average Loss: 1.172615, Training accuracy: 0.342130
# Epoch 0_65.145%:  Training average Loss: 1.171930, Training accuracy: 0.347865
# Epoch 0_66.213%:  Training average Loss: 1.171604, Training accuracy: 0.353557
# Epoch 0_67.281%:  Training average Loss: 1.171682, Training accuracy: 0.359270
# Epoch 0_68.349%:  Training average Loss: 1.171250, Training accuracy: 0.365208
# Epoch 0_69.417%:  Training average Loss: 1.170988, Training accuracy: 0.370687
# Epoch 0_70.485%:  Training average Loss: 1.170431, Training accuracy: 0.376539
# Epoch 0_71.553%:  Training average Loss: 1.169544, Training accuracy: 0.382520
# Epoch 0_72.621%:  Training average Loss: 1.169166, Training accuracy: 0.388340
# Epoch 0_73.689%:  Training average Loss: 1.168108, Training accuracy: 0.394652
# Epoch 0_74.757%:  Training average Loss: 1.167490, Training accuracy: 0.400771
# Epoch 0_75.825%:  Training average Loss: 1.167107, Training accuracy: 0.406677
# Epoch 0_76.893%:  Training average Loss: 1.166704, Training accuracy: 0.412529
# Epoch 0_77.961%:  Training average Loss: 1.166822, Training accuracy: 0.418221
# Epoch 0_79.029%:  Training average Loss: 1.166046, Training accuracy: 0.424063
# Epoch 0_80.097%:  Training average Loss: 1.165864, Training accuracy: 0.429766
# Epoch 0_81.164%:  Training average Loss: 1.165637, Training accuracy: 0.435608
# Epoch 0_82.232%:  Training average Loss: 1.165953, Training accuracy: 0.441076
# Epoch 0_83.300%:  Training average Loss: 1.165510, Training accuracy: 0.446960
# Epoch 0_84.368%:  Training average Loss: 1.164941, Training accuracy: 0.453069
# Epoch 0_85.436%:  Training average Loss: 1.164466, Training accuracy: 0.459071
# Epoch 0_86.504%:  Training average Loss: 1.163609, Training accuracy: 0.465211
# Epoch 0_87.572%:  Training average Loss: 1.163244, Training accuracy: 0.471128
# Epoch 0_88.640%:  Training average Loss: 1.162650, Training accuracy: 0.476873
# Epoch 0_89.708%:  Training average Loss: 1.162176, Training accuracy: 0.482672
# Epoch 0_90.776%:  Training average Loss: 1.161721, Training accuracy: 0.488407
# Epoch 0_91.844%:  Training average Loss: 1.161080, Training accuracy: 0.494324
# Epoch 0_92.912%:  Training average Loss: 1.160677, Training accuracy: 0.500219
# Epoch 0_93.980%:  Training average Loss: 1.160185, Training accuracy: 0.506082
# Epoch 0_95.048%:  Training average Loss: 1.159709, Training accuracy: 0.512041
# Epoch 0_96.116%:  Training average Loss: 1.159118, Training accuracy: 0.518182
# Epoch 0_97.184%:  Training average Loss: 1.159227, Training accuracy: 0.523799
# Epoch 0_98.252%:  Training average Loss: 1.158975, Training accuracy: 0.529449
# Epoch 0_99.320%:  Training average Loss: 1.158594, Training accuracy: 0.535312
# Epoch 0 :  Verification average Loss: 1.103861, Verification accuracy: 18.575990%,Total Time:437.834773
# Model is saved in model_dict/model_lstm/epoch_0_accuracy_0.185760
# Epoch 1_1.068%:  Training average Loss: 1.145981, Training accuracy: 0.005938
# Epoch 1_2.136%:  Training average Loss: 1.121292, Training accuracy: 0.011876
# Epoch 1_3.204%:  Training average Loss: 1.114879, Training accuracy: 0.017813
# Epoch 1_4.272%:  Training average Loss: 1.108580, Training accuracy: 0.023709
# Epoch 1_5.340%:  Training average Loss: 1.107985, Training accuracy: 0.029764
# Epoch 1_6.408%:  Training average Loss: 1.108191, Training accuracy: 0.035638
# Epoch 1_7.476%:  Training average Loss: 1.105103, Training accuracy: 0.041607
# Epoch 1_8.544%:  Training average Loss: 1.105275, Training accuracy: 0.047844
# Epoch 1_9.612%:  Training average Loss: 1.110178, Training accuracy: 0.053622
# Epoch 1_10.680%:  Training average Loss: 1.114960, Training accuracy: 0.059175
# Epoch 1_11.747%:  Training average Loss: 1.111443, Training accuracy: 0.065423
# Epoch 1_12.815%:  Training average Loss: 1.112253, Training accuracy: 0.071329
# Epoch 1_13.883%:  Training average Loss: 1.113320, Training accuracy: 0.077074
# Epoch 1_14.951%:  Training average Loss: 1.111852, Training accuracy: 0.083140
# Epoch 1_16.019%:  Training average Loss: 1.109581, Training accuracy: 0.089035
# Epoch 1_17.087%:  Training average Loss: 1.110177, Training accuracy: 0.094770
# Epoch 1_18.155%:  Training average Loss: 1.109195, Training accuracy: 0.100729
# Epoch 1_19.223%:  Training average Loss: 1.110222, Training accuracy: 0.106443
# Epoch 1_20.291%:  Training average Loss: 1.111304, Training accuracy: 0.112317
# Epoch 1_21.359%:  Training average Loss: 1.109590, Training accuracy: 0.118457
# Epoch 1_22.427%:  Training average Loss: 1.108294, Training accuracy: 0.124673
# Epoch 1_23.495%:  Training average Loss: 1.107500, Training accuracy: 0.130632
# Epoch 1_24.563%:  Training average Loss: 1.108302, Training accuracy: 0.136442
# Epoch 1_25.631%:  Training average Loss: 1.107193, Training accuracy: 0.142529
# Epoch 1_26.699%:  Training average Loss: 1.105584, Training accuracy: 0.148713
# Epoch 1_27.767%:  Training average Loss: 1.105137, Training accuracy: 0.154725
# Epoch 1_28.835%:  Training average Loss: 1.103942, Training accuracy: 0.160663
# Epoch 1_29.903%:  Training average Loss: 1.103244, Training accuracy: 0.166782
# Epoch 1_30.971%:  Training average Loss: 1.102312, Training accuracy: 0.172838
# Epoch 1_32.039%:  Training average Loss: 1.102285, Training accuracy: 0.178893
# Epoch 1_33.107%:  Training average Loss: 1.102832, Training accuracy: 0.184884
# Epoch 1_34.175%:  Training average Loss: 1.104038, Training accuracy: 0.190715
# Epoch 1_35.242%:  Training average Loss: 1.104898, Training accuracy: 0.196664
# Epoch 1_36.310%:  Training average Loss: 1.104796, Training accuracy: 0.202890
# Epoch 1_37.378%:  Training average Loss: 1.104044, Training accuracy: 0.209212
# Epoch 1_38.446%:  Training average Loss: 1.103572, Training accuracy: 0.215385
# Epoch 1_39.514%:  Training average Loss: 1.103220, Training accuracy: 0.221600
# Epoch 1_40.582%:  Training average Loss: 1.103138, Training accuracy: 0.227549
# Epoch 1_41.650%:  Training average Loss: 1.102451, Training accuracy: 0.233850
# Epoch 1_42.718%:  Training average Loss: 1.102729, Training accuracy: 0.239820
# Epoch 1_43.786%:  Training average Loss: 1.101348, Training accuracy: 0.246142
# Epoch 1_44.854%:  Training average Loss: 1.100784, Training accuracy: 0.252358
# Epoch 1_45.922%:  Training average Loss: 1.100472, Training accuracy: 0.258402
# Epoch 1_46.990%:  Training average Loss: 1.099944, Training accuracy: 0.264468
# Epoch 1_48.058%:  Training average Loss: 1.099997, Training accuracy: 0.270481
# Epoch 1_49.126%:  Training average Loss: 1.098720, Training accuracy: 0.276856
# Epoch 1_50.194%:  Training average Loss: 1.098830, Training accuracy: 0.283061
# Epoch 1_51.262%:  Training average Loss: 1.099997, Training accuracy: 0.288775
# Epoch 1_52.330%:  Training average Loss: 1.099210, Training accuracy: 0.294969
# Epoch 1_53.398%:  Training average Loss: 1.098290, Training accuracy: 0.301078
# Epoch 1_54.466%:  Training average Loss: 1.098763, Training accuracy: 0.306791
# Epoch 1_55.534%:  Training average Loss: 1.099349, Training accuracy: 0.312537
# Epoch 1_56.602%:  Training average Loss: 1.098181, Training accuracy: 0.318923
# Epoch 1_57.670%:  Training average Loss: 1.097495, Training accuracy: 0.324946
# Epoch 1_58.737%:  Training average Loss: 1.098129, Training accuracy: 0.330809
# Epoch 1_59.805%:  Training average Loss: 1.097436, Training accuracy: 0.336982
# Epoch 1_60.873%:  Training average Loss: 1.097147, Training accuracy: 0.342963
# Epoch 1_61.941%:  Training average Loss: 1.096774, Training accuracy: 0.348911
# Epoch 1_63.009%:  Training average Loss: 1.095989, Training accuracy: 0.355041
# Epoch 1_64.077%:  Training average Loss: 1.095794, Training accuracy: 0.360958
# Epoch 1_65.145%:  Training average Loss: 1.094873, Training accuracy: 0.367109
# Epoch 1_66.213%:  Training average Loss: 1.094167, Training accuracy: 0.373346
# Epoch 1_67.281%:  Training average Loss: 1.093422, Training accuracy: 0.379690
# Epoch 1_68.349%:  Training average Loss: 1.093511, Training accuracy: 0.385660
# Epoch 1_69.417%:  Training average Loss: 1.092696, Training accuracy: 0.391875
# Epoch 1_70.485%:  Training average Loss: 1.092785, Training accuracy: 0.397503
# Epoch 1_71.553%:  Training average Loss: 1.092517, Training accuracy: 0.403558
# Epoch 1_72.621%:  Training average Loss: 1.091735, Training accuracy: 0.409763
# Epoch 1_73.689%:  Training average Loss: 1.091256, Training accuracy: 0.416075
# Epoch 1_74.757%:  Training average Loss: 1.090600, Training accuracy: 0.422162
# Epoch 1_75.825%:  Training average Loss: 1.090318, Training accuracy: 0.428420
# Epoch 1_76.893%:  Training average Loss: 1.090055, Training accuracy: 0.434422
# Epoch 1_77.961%:  Training average Loss: 1.089858, Training accuracy: 0.440328
# Epoch 1_79.029%:  Training average Loss: 1.089277, Training accuracy: 0.446565
# Epoch 1_80.097%:  Training average Loss: 1.089310, Training accuracy: 0.452652
# Epoch 1_81.164%:  Training average Loss: 1.088593, Training accuracy: 0.458643
# Epoch 1_82.232%:  Training average Loss: 1.087910, Training accuracy: 0.464944
# Epoch 1_83.300%:  Training average Loss: 1.087343, Training accuracy: 0.471032
# Epoch 1_84.368%:  Training average Loss: 1.086731, Training accuracy: 0.477311
# Epoch 1_85.436%:  Training average Loss: 1.086128, Training accuracy: 0.483591
# Epoch 1_86.504%:  Training average Loss: 1.085647, Training accuracy: 0.489550
# Epoch 1_87.572%:  Training average Loss: 1.085663, Training accuracy: 0.495349
# Epoch 1_88.640%:  Training average Loss: 1.084769, Training accuracy: 0.501928
# Epoch 1_89.708%:  Training average Loss: 1.084557, Training accuracy: 0.508068
# Epoch 1_90.776%:  Training average Loss: 1.083923, Training accuracy: 0.514198
# Epoch 1_91.844%:  Training average Loss: 1.083502, Training accuracy: 0.520296
# Epoch 1_92.912%:  Training average Loss: 1.082667, Training accuracy: 0.526416
# Epoch 1_93.980%:  Training average Loss: 1.081746, Training accuracy: 0.532759
# Epoch 1_95.048%:  Training average Loss: 1.081474, Training accuracy: 0.538633
# Epoch 1_96.116%:  Training average Loss: 1.081122, Training accuracy: 0.544849
# Epoch 1_97.184%:  Training average Loss: 1.080670, Training accuracy: 0.550968
# Epoch 1_98.252%:  Training average Loss: 1.080314, Training accuracy: 0.557013
# Epoch 1_99.320%:  Training average Loss: 1.080135, Training accuracy: 0.563036
# Epoch 1 :  Verification average Loss: 1.046931, Verification accuracy: 19.099288%,Total Time:896.652040
# Model is saved in model_dict/model_lstm/epoch_1_accuracy_0.190993
# Epoch 2_1.068%:  Training average Loss: 1.020999, Training accuracy: 0.006280
# Epoch 2_2.136%:  Training average Loss: 1.052648, Training accuracy: 0.012335
# Epoch 2_3.204%:  Training average Loss: 1.055179, Training accuracy: 0.018294
# Epoch 2_4.272%:  Training average Loss: 1.057385, Training accuracy: 0.024317
# Epoch 2_5.340%:  Training average Loss: 1.064338, Training accuracy: 0.030127
# Epoch 2_6.408%:  Training average Loss: 1.058792, Training accuracy: 0.036428
# Epoch 2_7.476%:  Training average Loss: 1.062935, Training accuracy: 0.042248
# Epoch 2_8.544%:  Training average Loss: 1.065106, Training accuracy: 0.048314
# Epoch 2_9.612%:  Training average Loss: 1.066054, Training accuracy: 0.054263
# Epoch 2_10.680%:  Training average Loss: 1.056633, Training accuracy: 0.061055
# Epoch 2_11.747%:  Training average Loss: 1.051743, Training accuracy: 0.067495
# Epoch 2_12.815%:  Training average Loss: 1.049010, Training accuracy: 0.073742
# Epoch 2_13.883%:  Training average Loss: 1.050265, Training accuracy: 0.079744
# Epoch 2_14.951%:  Training average Loss: 1.047589, Training accuracy: 0.085906
# Epoch 2_16.019%:  Training average Loss: 1.048399, Training accuracy: 0.092004
# Epoch 2_17.087%:  Training average Loss: 1.048542, Training accuracy: 0.098380
# Epoch 2_18.155%:  Training average Loss: 1.047913, Training accuracy: 0.104681
# Epoch 2_19.223%:  Training average Loss: 1.047750, Training accuracy: 0.110811
# Epoch 2_20.291%:  Training average Loss: 1.047459, Training accuracy: 0.116973
# Epoch 2_21.359%:  Training average Loss: 1.048419, Training accuracy: 0.122900
# Epoch 2_22.427%:  Training average Loss: 1.046117, Training accuracy: 0.129254
# Epoch 2_23.495%:  Training average Loss: 1.045626, Training accuracy: 0.135449
# Epoch 2_24.563%:  Training average Loss: 1.044556, Training accuracy: 0.141664
# Epoch 2_25.631%:  Training average Loss: 1.044317, Training accuracy: 0.147730
# Epoch 2_26.699%:  Training average Loss: 1.043084, Training accuracy: 0.154010
# Epoch 2_27.767%:  Training average Loss: 1.042129, Training accuracy: 0.160161
# Epoch 2_28.835%:  Training average Loss: 1.041928, Training accuracy: 0.166377
# Epoch 2_29.903%:  Training average Loss: 1.041392, Training accuracy: 0.172613
# Epoch 2_30.971%:  Training average Loss: 1.039398, Training accuracy: 0.178957
# Epoch 2_32.039%:  Training average Loss: 1.039638, Training accuracy: 0.185023
# Epoch 2_33.107%:  Training average Loss: 1.038649, Training accuracy: 0.191292
# Epoch 2_34.175%:  Training average Loss: 1.039578, Training accuracy: 0.197251
# Epoch 2_35.242%:  Training average Loss: 1.039449, Training accuracy: 0.203552
# Epoch 2_36.310%:  Training average Loss: 1.039076, Training accuracy: 0.209703
# Epoch 2_37.378%:  Training average Loss: 1.038304, Training accuracy: 0.215983
# Epoch 2_38.446%:  Training average Loss: 1.038917, Training accuracy: 0.222006
# Epoch 2_39.514%:  Training average Loss: 1.039637, Training accuracy: 0.227955
# Epoch 2_40.582%:  Training average Loss: 1.039934, Training accuracy: 0.234085
# Epoch 2_41.650%:  Training average Loss: 1.039895, Training accuracy: 0.240279
# Epoch 2_42.718%:  Training average Loss: 1.040468, Training accuracy: 0.246217
# Epoch 2_43.786%:  Training average Loss: 1.040020, Training accuracy: 0.252507
# Epoch 2_44.854%:  Training average Loss: 1.040434, Training accuracy: 0.258327
# Epoch 2_45.922%:  Training average Loss: 1.039324, Training accuracy: 0.264938
# Epoch 2_46.990%:  Training average Loss: 1.038175, Training accuracy: 0.271314
# Epoch 2_48.058%:  Training average Loss: 1.038117, Training accuracy: 0.277540
# Epoch 2_49.126%:  Training average Loss: 1.038561, Training accuracy: 0.283745
# Epoch 2_50.194%:  Training average Loss: 1.038574, Training accuracy: 0.290067
# Epoch 2_51.262%:  Training average Loss: 1.037830, Training accuracy: 0.296314
# Epoch 2_52.330%:  Training average Loss: 1.037245, Training accuracy: 0.302679
# Epoch 2_53.398%:  Training average Loss: 1.038016, Training accuracy: 0.308799
# Epoch 2_54.466%:  Training average Loss: 1.037779, Training accuracy: 0.315068
# Epoch 2_55.534%:  Training average Loss: 1.037365, Training accuracy: 0.321475
# Epoch 2_56.602%:  Training average Loss: 1.037217, Training accuracy: 0.327638
# Epoch 2_57.670%:  Training average Loss: 1.038090, Training accuracy: 0.333714
# Epoch 2_58.737%:  Training average Loss: 1.037658, Training accuracy: 0.340090
# Epoch 2_59.805%:  Training average Loss: 1.037623, Training accuracy: 0.346391
# Epoch 2_60.873%:  Training average Loss: 1.036760, Training accuracy: 0.352799
# Epoch 2_61.941%:  Training average Loss: 1.035948, Training accuracy: 0.359217
# Epoch 2_63.009%:  Training average Loss: 1.035133, Training accuracy: 0.365699
# Epoch 2_64.077%:  Training average Loss: 1.034882, Training accuracy: 0.371947
# Epoch 2_65.145%:  Training average Loss: 1.035370, Training accuracy: 0.378077
# Epoch 2_66.213%:  Training average Loss: 1.034695, Training accuracy: 0.384378
# Epoch 2_67.281%:  Training average Loss: 1.034837, Training accuracy: 0.390423
# Epoch 2_68.349%:  Training average Loss: 1.034821, Training accuracy: 0.396734
# Epoch 2_69.417%:  Training average Loss: 1.033774, Training accuracy: 0.403323
# Epoch 2_70.485%:  Training average Loss: 1.033167, Training accuracy: 0.409667
# Epoch 2_71.553%:  Training average Loss: 1.032928, Training accuracy: 0.416053
# Epoch 2_72.621%:  Training average Loss: 1.031952, Training accuracy: 0.422418
# Epoch 2_73.689%:  Training average Loss: 1.030852, Training accuracy: 0.428912
# Epoch 2_74.757%:  Training average Loss: 1.030956, Training accuracy: 0.434978
# Epoch 2_75.825%:  Training average Loss: 1.030666, Training accuracy: 0.441182
# Epoch 2_76.893%:  Training average Loss: 1.030114, Training accuracy: 0.447612
# Epoch 2_77.961%:  Training average Loss: 1.029562, Training accuracy: 0.453987
# Epoch 2_79.029%:  Training average Loss: 1.028960, Training accuracy: 0.460374
# Epoch 2_80.097%:  Training average Loss: 1.028035, Training accuracy: 0.466899
# Epoch 2_81.164%:  Training average Loss: 1.028125, Training accuracy: 0.473093
# Epoch 2_82.232%:  Training average Loss: 1.027727, Training accuracy: 0.479340
# Epoch 2_83.300%:  Training average Loss: 1.028215, Training accuracy: 0.485364
# Epoch 2_84.368%:  Training average Loss: 1.027838, Training accuracy: 0.491536
# Epoch 2_85.436%:  Training average Loss: 1.027732, Training accuracy: 0.497560
# Epoch 2_86.504%:  Training average Loss: 1.027374, Training accuracy: 0.503914
# Epoch 2_87.572%:  Training average Loss: 1.027230, Training accuracy: 0.509852
# Epoch 2_88.640%:  Training average Loss: 1.027175, Training accuracy: 0.515939
# Epoch 2_89.708%:  Training average Loss: 1.027307, Training accuracy: 0.522005
# Epoch 2_90.776%:  Training average Loss: 1.027589, Training accuracy: 0.528295
# Epoch 2_91.844%:  Training average Loss: 1.027116, Training accuracy: 0.534607
# Epoch 2_92.912%:  Training average Loss: 1.027767, Training accuracy: 0.540246
# Epoch 2_93.980%:  Training average Loss: 1.027022, Training accuracy: 0.546600
# Epoch 2_95.048%:  Training average Loss: 1.027054, Training accuracy: 0.552837
# Epoch 2_96.116%:  Training average Loss: 1.026416, Training accuracy: 0.559277
# Epoch 2_97.184%:  Training average Loss: 1.026512, Training accuracy: 0.565471
# Epoch 2_98.252%:  Training average Loss: 1.026884, Training accuracy: 0.571548
# Epoch 2_99.320%:  Training average Loss: 1.027259, Training accuracy: 0.577517
# Epoch 2 :  Verification average Loss: 1.013875, Verification accuracy: 19.467732%,Total Time:1357.854301
# Model is saved in model_dict/model_lstm/epoch_2_accuracy_0.194677
# Epoch 3_1.068%:  Training average Loss: 0.980713, Training accuracy: 0.006504
# Epoch 3_2.136%:  Training average Loss: 0.988285, Training accuracy: 0.012794
# Epoch 3_3.204%:  Training average Loss: 1.000878, Training accuracy: 0.019031
# Epoch 3_4.272%:  Training average Loss: 0.999302, Training accuracy: 0.025375
# Epoch 3_5.340%:  Training average Loss: 0.995229, Training accuracy: 0.031782
# Epoch 3_6.408%:  Training average Loss: 0.999693, Training accuracy: 0.037923
# Epoch 3_7.476%:  Training average Loss: 0.994117, Training accuracy: 0.044331
# Epoch 3_8.544%:  Training average Loss: 0.995591, Training accuracy: 0.050738
# Epoch 3_9.612%:  Training average Loss: 0.999801, Training accuracy: 0.056847
# Epoch 3_10.680%:  Training average Loss: 0.999374, Training accuracy: 0.063095
# Epoch 3_11.747%:  Training average Loss: 1.002039, Training accuracy: 0.069310
# Epoch 3_12.815%:  Training average Loss: 1.000752, Training accuracy: 0.075536
# Epoch 3_13.883%:  Training average Loss: 0.998392, Training accuracy: 0.082158
# Epoch 3_14.951%:  Training average Loss: 1.002144, Training accuracy: 0.088160
# Epoch 3_16.019%:  Training average Loss: 0.999720, Training accuracy: 0.094525
# Epoch 3_17.087%:  Training average Loss: 0.999117, Training accuracy: 0.100996
# Epoch 3_18.155%:  Training average Loss: 0.999406, Training accuracy: 0.107319
# Epoch 3_19.223%:  Training average Loss: 1.000653, Training accuracy: 0.113491
# Epoch 3_20.291%:  Training average Loss: 1.001224, Training accuracy: 0.119760
# Epoch 3_21.359%:  Training average Loss: 0.999846, Training accuracy: 0.125976
# Epoch 3_22.427%:  Training average Loss: 1.000976, Training accuracy: 0.131914
# Epoch 3_23.495%:  Training average Loss: 1.000191, Training accuracy: 0.138236
# Epoch 3_24.563%:  Training average Loss: 0.999622, Training accuracy: 0.144921
# Epoch 3_25.631%:  Training average Loss: 1.000772, Training accuracy: 0.151105
# Epoch 3_26.699%:  Training average Loss: 1.000904, Training accuracy: 0.157395
# Epoch 3_27.767%:  Training average Loss: 1.001579, Training accuracy: 0.163653
# Epoch 3_28.835%:  Training average Loss: 0.999978, Training accuracy: 0.170008
# Epoch 3_29.903%:  Training average Loss: 1.000848, Training accuracy: 0.175999
# Epoch 3_30.971%:  Training average Loss: 1.000611, Training accuracy: 0.182449
# Epoch 3_32.039%:  Training average Loss: 1.000747, Training accuracy: 0.188675
# Epoch 3_33.107%:  Training average Loss: 1.001705, Training accuracy: 0.194795
# Epoch 3_34.175%:  Training average Loss: 1.001657, Training accuracy: 0.201010
# Epoch 3_35.242%:  Training average Loss: 1.000604, Training accuracy: 0.207407
# Epoch 3_36.310%:  Training average Loss: 1.001224, Training accuracy: 0.213687
# Epoch 3_37.378%:  Training average Loss: 1.001705, Training accuracy: 0.219999
# Epoch 3_38.446%:  Training average Loss: 1.001985, Training accuracy: 0.226364
# Epoch 3_39.514%:  Training average Loss: 1.002544, Training accuracy: 0.232579
# Epoch 3_40.582%:  Training average Loss: 1.002919, Training accuracy: 0.238730
# Epoch 3_41.650%:  Training average Loss: 1.002747, Training accuracy: 0.245170
# Epoch 3_42.718%:  Training average Loss: 1.002336, Training accuracy: 0.251749
# Epoch 3_43.786%:  Training average Loss: 1.002661, Training accuracy: 0.257975
# Epoch 3_44.854%:  Training average Loss: 1.003914, Training accuracy: 0.263988
# Epoch 3_45.922%:  Training average Loss: 1.003439, Training accuracy: 0.270374
# Epoch 3_46.990%:  Training average Loss: 1.002711, Training accuracy: 0.276974
# Epoch 3_48.058%:  Training average Loss: 1.001921, Training accuracy: 0.283446
# Epoch 3_49.126%:  Training average Loss: 1.001907, Training accuracy: 0.289789
# Epoch 3_50.194%:  Training average Loss: 1.001828, Training accuracy: 0.296015
# Epoch 3_51.262%:  Training average Loss: 1.001650, Training accuracy: 0.302295
# Epoch 3_52.330%:  Training average Loss: 1.001815, Training accuracy: 0.308446
# Epoch 3_53.398%:  Training average Loss: 1.001714, Training accuracy: 0.314801
# Epoch 3_54.466%:  Training average Loss: 1.002044, Training accuracy: 0.320984
# Epoch 3_55.534%:  Training average Loss: 1.001773, Training accuracy: 0.327264
# Epoch 3_56.602%:  Training average Loss: 1.001237, Training accuracy: 0.333736
# Epoch 3_57.670%:  Training average Loss: 1.000241, Training accuracy: 0.340357
# Epoch 3_58.737%:  Training average Loss: 0.999871, Training accuracy: 0.346839
# Epoch 3_59.805%:  Training average Loss: 0.999909, Training accuracy: 0.352841
# Epoch 3_60.873%:  Training average Loss: 1.000166, Training accuracy: 0.359078
# Epoch 3_61.941%:  Training average Loss: 1.000894, Training accuracy: 0.364931
# Epoch 3_63.009%:  Training average Loss: 1.000714, Training accuracy: 0.371178
# Epoch 3_64.077%:  Training average Loss: 1.000208, Training accuracy: 0.377671
# Epoch 3_65.145%:  Training average Loss: 1.000618, Training accuracy: 0.383908
# Epoch 3_66.213%:  Training average Loss: 1.001193, Training accuracy: 0.389664
# Epoch 3_67.281%:  Training average Loss: 1.000829, Training accuracy: 0.396104
# Epoch 3_68.349%:  Training average Loss: 1.001927, Training accuracy: 0.402213
# Epoch 3_69.417%:  Training average Loss: 1.002481, Training accuracy: 0.408343
# Epoch 3_70.485%:  Training average Loss: 1.002171, Training accuracy: 0.414644
# Epoch 3_71.553%:  Training average Loss: 1.002244, Training accuracy: 0.420720
# Epoch 3_72.621%:  Training average Loss: 1.001860, Training accuracy: 0.427150
# Epoch 3_73.689%:  Training average Loss: 1.001540, Training accuracy: 0.433579
# Epoch 3_74.757%:  Training average Loss: 1.001406, Training accuracy: 0.440093
# Epoch 3_75.825%:  Training average Loss: 1.001383, Training accuracy: 0.446394
# Epoch 3_76.893%:  Training average Loss: 1.001428, Training accuracy: 0.452631
# Epoch 3_77.961%:  Training average Loss: 1.001970, Training accuracy: 0.458590
# Epoch 3_79.029%:  Training average Loss: 1.002326, Training accuracy: 0.464774
# Epoch 3_80.097%:  Training average Loss: 1.002465, Training accuracy: 0.470775
# Epoch 3_81.164%:  Training average Loss: 1.002592, Training accuracy: 0.477023
# Epoch 3_82.232%:  Training average Loss: 1.002442, Training accuracy: 0.483238
# Epoch 3_83.300%:  Training average Loss: 1.002453, Training accuracy: 0.489422
# Epoch 3_84.368%:  Training average Loss: 1.002511, Training accuracy: 0.495744
# Epoch 3_85.436%:  Training average Loss: 1.002628, Training accuracy: 0.501789
# Epoch 3_86.504%:  Training average Loss: 1.002943, Training accuracy: 0.507930
# Epoch 3_87.572%:  Training average Loss: 1.002853, Training accuracy: 0.514305
# Epoch 3_88.640%:  Training average Loss: 1.003057, Training accuracy: 0.520435
# Epoch 3_89.708%:  Training average Loss: 1.003250, Training accuracy: 0.526683
# Epoch 3_90.776%:  Training average Loss: 1.003615, Training accuracy: 0.532631
# Epoch 3_91.844%:  Training average Loss: 1.004016, Training accuracy: 0.538676
# Epoch 3_92.912%:  Training average Loss: 1.003798, Training accuracy: 0.545223
# Epoch 3_93.980%:  Training average Loss: 1.003570, Training accuracy: 0.551705
# Epoch 3_95.048%:  Training average Loss: 1.003761, Training accuracy: 0.557910
# Epoch 3_96.116%:  Training average Loss: 1.003668, Training accuracy: 0.564008
# Epoch 3_97.184%:  Training average Loss: 1.003713, Training accuracy: 0.570277
# Epoch 3_98.252%:  Training average Loss: 1.003795, Training accuracy: 0.576588
# Epoch 3_99.320%:  Training average Loss: 1.004251, Training accuracy: 0.582825
# Epoch 3 :  Verification average Loss: 0.994800, Verification accuracy: 19.287248%,Total Time:1828.546390
# Epoch 4_1.068%:  Training average Loss: 0.976827, Training accuracy: 0.006482
# Epoch 4_2.136%:  Training average Loss: 0.979272, Training accuracy: 0.012901
# Epoch 4_3.204%:  Training average Loss: 0.977669, Training accuracy: 0.019351
# Epoch 4_4.272%:  Training average Loss: 0.978102, Training accuracy: 0.025877
# Epoch 4_5.340%:  Training average Loss: 0.980612, Training accuracy: 0.032284
# Epoch 4_6.408%:  Training average Loss: 0.984991, Training accuracy: 0.038735
# Epoch 4_7.476%:  Training average Loss: 0.982805, Training accuracy: 0.045335
# Epoch 4_8.544%:  Training average Loss: 0.986202, Training accuracy: 0.051582
# Epoch 4_9.612%:  Training average Loss: 0.984197, Training accuracy: 0.057830
# Epoch 4_10.680%:  Training average Loss: 0.982642, Training accuracy: 0.064216
# Epoch 4_11.747%:  Training average Loss: 0.983276, Training accuracy: 0.070677
# Epoch 4_12.815%:  Training average Loss: 0.983148, Training accuracy: 0.077128
# Epoch 4_13.883%:  Training average Loss: 0.982955, Training accuracy: 0.083258
# Epoch 4_14.951%:  Training average Loss: 0.983111, Training accuracy: 0.089633
# Epoch 4_16.019%:  Training average Loss: 0.985584, Training accuracy: 0.095913
# Epoch 4_17.087%:  Training average Loss: 0.988729, Training accuracy: 0.102054
# Epoch 4_18.155%:  Training average Loss: 0.987704, Training accuracy: 0.108504
# Epoch 4_19.223%:  Training average Loss: 0.987080, Training accuracy: 0.114826
# Epoch 4_20.291%:  Training average Loss: 0.989591, Training accuracy: 0.120935
# Epoch 4_21.359%:  Training average Loss: 0.990814, Training accuracy: 0.127183
# Epoch 4_22.427%:  Training average Loss: 0.988951, Training accuracy: 0.133612
# Epoch 4_23.495%:  Training average Loss: 0.989718, Training accuracy: 0.139902
# Epoch 4_24.563%:  Training average Loss: 0.991067, Training accuracy: 0.146000
# Epoch 4_25.631%:  Training average Loss: 0.989656, Training accuracy: 0.152461
# Epoch 4_26.699%:  Training average Loss: 0.990032, Training accuracy: 0.158698
# Epoch 4_27.767%:  Training average Loss: 0.989525, Training accuracy: 0.165074
# Epoch 4_28.835%:  Training average Loss: 0.989921, Training accuracy: 0.171332
# Epoch 4_29.903%:  Training average Loss: 0.989869, Training accuracy: 0.177633
# Epoch 4_30.971%:  Training average Loss: 0.989707, Training accuracy: 0.183923
# Epoch 4_32.039%:  Training average Loss: 0.987819, Training accuracy: 0.190470
# Epoch 4_33.107%:  Training average Loss: 0.988091, Training accuracy: 0.196568
# Epoch 4_34.175%:  Training average Loss: 0.990042, Training accuracy: 0.202569
# Epoch 4_35.242%:  Training average Loss: 0.990602, Training accuracy: 0.208635
# Epoch 4_36.310%:  Training average Loss: 0.990657, Training accuracy: 0.214936
# Epoch 4_37.378%:  Training average Loss: 0.990298, Training accuracy: 0.221291
# Epoch 4_38.446%:  Training average Loss: 0.990209, Training accuracy: 0.227666
# Epoch 4_39.514%:  Training average Loss: 0.990609, Training accuracy: 0.233903
# Epoch 4_40.582%:  Training average Loss: 0.989069, Training accuracy: 0.240546
# Epoch 4_41.650%:  Training average Loss: 0.987856, Training accuracy: 0.247231
# Epoch 4_42.718%:  Training average Loss: 0.987472, Training accuracy: 0.253735
# Epoch 4_43.786%:  Training average Loss: 0.987275, Training accuracy: 0.260186
# Epoch 4_44.854%:  Training average Loss: 0.987628, Training accuracy: 0.266252
# Epoch 4_45.922%:  Training average Loss: 0.988529, Training accuracy: 0.272339
# Epoch 4_46.990%:  Training average Loss: 0.988419, Training accuracy: 0.278554
# Epoch 4_48.058%:  Training average Loss: 0.988924, Training accuracy: 0.284823
# Epoch 4_49.126%:  Training average Loss: 0.989621, Training accuracy: 0.291103
# Epoch 4_50.194%:  Training average Loss: 0.989229, Training accuracy: 0.297585
# Epoch 4_51.262%:  Training average Loss: 0.990267, Training accuracy: 0.303641
# Epoch 4_52.330%:  Training average Loss: 0.989887, Training accuracy: 0.310112
# Epoch 4_53.398%:  Training average Loss: 0.989438, Training accuracy: 0.316648
# Epoch 4_54.466%:  Training average Loss: 0.988622, Training accuracy: 0.323366
# Epoch 4_55.534%:  Training average Loss: 0.989670, Training accuracy: 0.329250
# Epoch 4_56.602%:  Training average Loss: 0.990347, Training accuracy: 0.335209
# Epoch 4_57.670%:  Training average Loss: 0.989972, Training accuracy: 0.341521
# Epoch 4_58.737%:  Training average Loss: 0.990449, Training accuracy: 0.347736
# Epoch 4_59.805%:  Training average Loss: 0.990769, Training accuracy: 0.353931
# Epoch 4_60.873%:  Training average Loss: 0.990165, Training accuracy: 0.360456
# Epoch 4_61.941%:  Training average Loss: 0.990100, Training accuracy: 0.366746
# Epoch 4_63.009%:  Training average Loss: 0.989926, Training accuracy: 0.373058
# Epoch 4_64.077%:  Training average Loss: 0.990190, Training accuracy: 0.379262
# Epoch 4_65.145%:  Training average Loss: 0.990782, Training accuracy: 0.385467
# Epoch 4_66.213%:  Training average Loss: 0.991354, Training accuracy: 0.391715
# Epoch 4_67.281%:  Training average Loss: 0.991427, Training accuracy: 0.398090
# Epoch 4_68.349%:  Training average Loss: 0.991563, Training accuracy: 0.404359
# Epoch 4_69.417%:  Training average Loss: 0.990708, Training accuracy: 0.411045
# Epoch 4_70.485%:  Training average Loss: 0.990251, Training accuracy: 0.417346
# Epoch 4_71.553%:  Training average Loss: 0.989827, Training accuracy: 0.423679
# Epoch 4_72.621%:  Training average Loss: 0.989656, Training accuracy: 0.429916
# Epoch 4_73.689%:  Training average Loss: 0.989122, Training accuracy: 0.436441
# Epoch 4_74.757%:  Training average Loss: 0.989739, Training accuracy: 0.442592
# Epoch 4_75.825%:  Training average Loss: 0.989885, Training accuracy: 0.448722
# Epoch 4_76.893%:  Training average Loss: 0.988977, Training accuracy: 0.455290
# Epoch 4_77.961%:  Training average Loss: 0.988482, Training accuracy: 0.461762
# Epoch 4_79.029%:  Training average Loss: 0.988688, Training accuracy: 0.467988
# Epoch 4_80.097%:  Training average Loss: 0.988435, Training accuracy: 0.474257
# Epoch 4_81.164%:  Training average Loss: 0.987982, Training accuracy: 0.480804
# Epoch 4_82.232%:  Training average Loss: 0.987980, Training accuracy: 0.487008
# Epoch 4_83.300%:  Training average Loss: 0.988235, Training accuracy: 0.493277
# Epoch 4_84.368%:  Training average Loss: 0.987979, Training accuracy: 0.499600
# Epoch 4_85.436%:  Training average Loss: 0.987898, Training accuracy: 0.505836
# Epoch 4_86.504%:  Training average Loss: 0.987853, Training accuracy: 0.512447
# Epoch 4_87.572%:  Training average Loss: 0.987806, Training accuracy: 0.518833
# Epoch 4_88.640%:  Training average Loss: 0.987904, Training accuracy: 0.525294
# Epoch 4_89.708%:  Training average Loss: 0.987979, Training accuracy: 0.531478
# Epoch 4_90.776%:  Training average Loss: 0.987769, Training accuracy: 0.537907
# Epoch 4_91.844%:  Training average Loss: 0.988159, Training accuracy: 0.544048
# Epoch 4_92.912%:  Training average Loss: 0.988241, Training accuracy: 0.550114
# Epoch 4_93.980%:  Training average Loss: 0.988322, Training accuracy: 0.556383
# Epoch 4_95.048%:  Training average Loss: 0.987914, Training accuracy: 0.562876
# Epoch 4_96.116%:  Training average Loss: 0.988599, Training accuracy: 0.568771
# Epoch 4_97.184%:  Training average Loss: 0.988803, Training accuracy: 0.574912
# Epoch 4_98.252%:  Training average Loss: 0.989345, Training accuracy: 0.580967
# Epoch 4_99.320%:  Training average Loss: 0.989229, Training accuracy: 0.587481
# Epoch 4 :  Verification average Loss: 0.971756, Verification accuracy: 19.832972%,Total Time:2282.103585
# Model is saved in model_dict/model_lstm/epoch_4_accuracy_0.198330
# Epoch 5_1.068%:  Training average Loss: 1.007613, Training accuracy: 0.006194
# Epoch 5_2.136%:  Training average Loss: 0.996167, Training accuracy: 0.012548
# Epoch 5_3.204%:  Training average Loss: 0.989543, Training accuracy: 0.018732
# Epoch 5_4.272%:  Training average Loss: 0.995542, Training accuracy: 0.024958
# Epoch 5_5.340%:  Training average Loss: 0.989561, Training accuracy: 0.031547
# Epoch 5_6.408%:  Training average Loss: 0.986745, Training accuracy: 0.037976
# Epoch 5_7.476%:  Training average Loss: 0.986726, Training accuracy: 0.044352
# Epoch 5_8.544%:  Training average Loss: 0.984375, Training accuracy: 0.050792
# Epoch 5_9.612%:  Training average Loss: 0.983863, Training accuracy: 0.057264
# Epoch 5_10.680%:  Training average Loss: 0.980824, Training accuracy: 0.063479
# Epoch 5_11.747%:  Training average Loss: 0.984776, Training accuracy: 0.069759
# Epoch 5_12.815%:  Training average Loss: 0.978532, Training accuracy: 0.076433
# Epoch 5_13.883%:  Training average Loss: 0.977489, Training accuracy: 0.082863
# Epoch 5_14.951%:  Training average Loss: 0.978448, Training accuracy: 0.089110
# Epoch 5_16.019%:  Training average Loss: 0.980337, Training accuracy: 0.095411
# Epoch 5_17.087%:  Training average Loss: 0.979384, Training accuracy: 0.101808
# Epoch 5_18.155%:  Training average Loss: 0.979495, Training accuracy: 0.108248
# Epoch 5_19.223%:  Training average Loss: 0.979149, Training accuracy: 0.114463
# Epoch 5_20.291%:  Training average Loss: 0.978322, Training accuracy: 0.120903
# Epoch 5_21.359%:  Training average Loss: 0.977243, Training accuracy: 0.127311
# Epoch 5_22.427%:  Training average Loss: 0.976893, Training accuracy: 0.133686
# Epoch 5_23.495%:  Training average Loss: 0.977623, Training accuracy: 0.139838
# Epoch 5_24.563%:  Training average Loss: 0.977554, Training accuracy: 0.146182
# Epoch 5_25.631%:  Training average Loss: 0.977142, Training accuracy: 0.152547
# Epoch 5_26.699%:  Training average Loss: 0.976572, Training accuracy: 0.158954
# Epoch 5_27.767%:  Training average Loss: 0.976243, Training accuracy: 0.165341
# Epoch 5_28.835%:  Training average Loss: 0.974854, Training accuracy: 0.171898
# Epoch 5_29.903%:  Training average Loss: 0.975679, Training accuracy: 0.178188
# Epoch 5_30.971%:  Training average Loss: 0.976450, Training accuracy: 0.184532
# Epoch 5_32.039%:  Training average Loss: 0.976659, Training accuracy: 0.190769
# Epoch 5_33.107%:  Training average Loss: 0.975892, Training accuracy: 0.197315
# Epoch 5_34.175%:  Training average Loss: 0.975136, Training accuracy: 0.203680
# Epoch 5_35.242%:  Training average Loss: 0.973340, Training accuracy: 0.210355
# Epoch 5_36.310%:  Training average Loss: 0.973388, Training accuracy: 0.216741
# Epoch 5_37.378%:  Training average Loss: 0.974524, Training accuracy: 0.223010
# Epoch 5_38.446%:  Training average Loss: 0.973974, Training accuracy: 0.229407
# Epoch 5_39.514%:  Training average Loss: 0.974168, Training accuracy: 0.235847
# Epoch 5_40.582%:  Training average Loss: 0.974795, Training accuracy: 0.242127
# Epoch 5_41.650%:  Training average Loss: 0.976334, Training accuracy: 0.248150
# Epoch 5_42.718%:  Training average Loss: 0.976220, Training accuracy: 0.254525
# Epoch 5_43.786%:  Training average Loss: 0.976211, Training accuracy: 0.260858
# Epoch 5_44.854%:  Training average Loss: 0.976648, Training accuracy: 0.267320
# Epoch 5_45.922%:  Training average Loss: 0.976613, Training accuracy: 0.273588
# Epoch 5_46.990%:  Training average Loss: 0.976740, Training accuracy: 0.279751
# Epoch 5_48.058%:  Training average Loss: 0.976782, Training accuracy: 0.286019
# Epoch 5_49.126%:  Training average Loss: 0.976340, Training accuracy: 0.292502
# Epoch 5_50.194%:  Training average Loss: 0.975956, Training accuracy: 0.298963
# Epoch 5_51.262%:  Training average Loss: 0.975924, Training accuracy: 0.305392
# Epoch 5_52.330%:  Training average Loss: 0.976166, Training accuracy: 0.311618
# Epoch 5_53.398%:  Training average Loss: 0.975793, Training accuracy: 0.318229
# Epoch 5_54.466%:  Training average Loss: 0.975879, Training accuracy: 0.324519
# Epoch 5_55.534%:  Training average Loss: 0.976465, Training accuracy: 0.330660
# Epoch 5_56.602%:  Training average Loss: 0.976157, Training accuracy: 0.337036
# Epoch 5_57.670%:  Training average Loss: 0.976876, Training accuracy: 0.343059
# Epoch 5_58.737%:  Training average Loss: 0.976667, Training accuracy: 0.349499
# Epoch 5_59.805%:  Training average Loss: 0.977151, Training accuracy: 0.355618
# Epoch 5_60.873%:  Training average Loss: 0.977377, Training accuracy: 0.361930
# Epoch 5_61.941%:  Training average Loss: 0.977807, Training accuracy: 0.368113
# Epoch 5_63.009%:  Training average Loss: 0.977661, Training accuracy: 0.374457
# Epoch 5_64.077%:  Training average Loss: 0.977800, Training accuracy: 0.380832
# Epoch 5_65.145%:  Training average Loss: 0.977888, Training accuracy: 0.387411
# Epoch 5_66.213%:  Training average Loss: 0.978493, Training accuracy: 0.393466
# Epoch 5_67.281%:  Training average Loss: 0.978526, Training accuracy: 0.399757
# Epoch 5_68.349%:  Training average Loss: 0.978072, Training accuracy: 0.406218
# Epoch 5_69.417%:  Training average Loss: 0.977679, Training accuracy: 0.412561
# Epoch 5_70.485%:  Training average Loss: 0.978488, Training accuracy: 0.418798
# Epoch 5_71.553%:  Training average Loss: 0.978852, Training accuracy: 0.424907
# Epoch 5_72.621%:  Training average Loss: 0.978858, Training accuracy: 0.431229
# Epoch 5_73.689%:  Training average Loss: 0.978850, Training accuracy: 0.437722
# Epoch 5_74.757%:  Training average Loss: 0.979311, Training accuracy: 0.443970
# Epoch 5_75.825%:  Training average Loss: 0.979722, Training accuracy: 0.450228
# Epoch 5_76.893%:  Training average Loss: 0.980342, Training accuracy: 0.456230
# Epoch 5_77.961%:  Training average Loss: 0.979937, Training accuracy: 0.462691
# Epoch 5_79.029%:  Training average Loss: 0.980242, Training accuracy: 0.469077
# Epoch 5_80.097%:  Training average Loss: 0.980332, Training accuracy: 0.475474
# Epoch 5_81.164%:  Training average Loss: 0.980525, Training accuracy: 0.481391
# Epoch 5_82.232%:  Training average Loss: 0.980443, Training accuracy: 0.487628
# Epoch 5_83.300%:  Training average Loss: 0.980535, Training accuracy: 0.493886
# Epoch 5_84.368%:  Training average Loss: 0.980511, Training accuracy: 0.500187
# Epoch 5_85.436%:  Training average Loss: 0.980534, Training accuracy: 0.506584
# Epoch 5_86.504%:  Training average Loss: 0.980071, Training accuracy: 0.513141
# Epoch 5_87.572%:  Training average Loss: 0.980219, Training accuracy: 0.519453
# Epoch 5_88.640%:  Training average Loss: 0.980901, Training accuracy: 0.525572
# Epoch 5_89.708%:  Training average Loss: 0.980648, Training accuracy: 0.532364
# Epoch 5_90.776%:  Training average Loss: 0.980501, Training accuracy: 0.538922
# Epoch 5_91.844%:  Training average Loss: 0.979966, Training accuracy: 0.545596
# Epoch 5_92.912%:  Training average Loss: 0.979749, Training accuracy: 0.552239
# Epoch 5_93.980%:  Training average Loss: 0.979625, Training accuracy: 0.558519
# Epoch 5_95.048%:  Training average Loss: 0.979277, Training accuracy: 0.565097
# Epoch 5_96.116%:  Training average Loss: 0.979551, Training accuracy: 0.571387
# Epoch 5_97.184%:  Training average Loss: 0.979289, Training accuracy: 0.577784
# Epoch 5_98.252%:  Training average Loss: 0.979240, Training accuracy: 0.584021
# Epoch 5_99.320%:  Training average Loss: 0.979205, Training accuracy: 0.590141
# Epoch 5 :  Verification average Loss: 0.962036, Verification accuracy: 20.076465%,Total Time:2731.556608
# Model is saved in model_dict/model_lstm/epoch_5_accuracy_0.200765
# Epoch 6_1.068%:  Training average Loss: 0.973126, Training accuracy: 0.006408
# Epoch 6_2.136%:  Training average Loss: 0.974664, Training accuracy: 0.012719
# Epoch 6_3.204%:  Training average Loss: 0.977029, Training accuracy: 0.019138
# Epoch 6_4.272%:  Training average Loss: 0.965549, Training accuracy: 0.025524
# Epoch 6_5.340%:  Training average Loss: 0.964144, Training accuracy: 0.031932
# Epoch 6_6.408%:  Training average Loss: 0.960736, Training accuracy: 0.038318
# Epoch 6_7.476%:  Training average Loss: 0.964323, Training accuracy: 0.044779
# Epoch 6_8.544%:  Training average Loss: 0.963649, Training accuracy: 0.051198
# Epoch 6_9.612%:  Training average Loss: 0.961410, Training accuracy: 0.057509
# Epoch 6_10.680%:  Training average Loss: 0.962304, Training accuracy: 0.064077
# Epoch 6_11.747%:  Training average Loss: 0.964669, Training accuracy: 0.070335
# Epoch 6_12.815%:  Training average Loss: 0.963151, Training accuracy: 0.076925
# Epoch 6_13.883%:  Training average Loss: 0.967762, Training accuracy: 0.083322
# Epoch 6_14.951%:  Training average Loss: 0.968522, Training accuracy: 0.089751
# Epoch 6_16.019%:  Training average Loss: 0.970133, Training accuracy: 0.096137
# Epoch 6_17.087%:  Training average Loss: 0.971155, Training accuracy: 0.102534
# Epoch 6_18.155%:  Training average Loss: 0.971496, Training accuracy: 0.108921
# Epoch 6_19.223%:  Training average Loss: 0.975640, Training accuracy: 0.114901
# Epoch 6_20.291%:  Training average Loss: 0.972158, Training accuracy: 0.121437
# Epoch 6_21.359%:  Training average Loss: 0.970514, Training accuracy: 0.127962
# Epoch 6_22.427%:  Training average Loss: 0.970445, Training accuracy: 0.134402
# Epoch 6_23.495%:  Training average Loss: 0.969635, Training accuracy: 0.140692
# Epoch 6_24.563%:  Training average Loss: 0.968705, Training accuracy: 0.147036
# Epoch 6_25.631%:  Training average Loss: 0.966480, Training accuracy: 0.153839
# Epoch 6_26.699%:  Training average Loss: 0.968391, Training accuracy: 0.160001
# Epoch 6_27.767%:  Training average Loss: 0.970014, Training accuracy: 0.166345
# Epoch 6_28.835%:  Training average Loss: 0.969856, Training accuracy: 0.172859
# Epoch 6_29.903%:  Training average Loss: 0.969985, Training accuracy: 0.178946
# Epoch 6_30.971%:  Training average Loss: 0.972117, Training accuracy: 0.185119
# Epoch 6_32.039%:  Training average Loss: 0.973430, Training accuracy: 0.191121
# Epoch 6_33.107%:  Training average Loss: 0.974463, Training accuracy: 0.197337
# Epoch 6_34.175%:  Training average Loss: 0.974438, Training accuracy: 0.203734
# Epoch 6_35.242%:  Training average Loss: 0.973737, Training accuracy: 0.210013
# Epoch 6_36.310%:  Training average Loss: 0.974501, Training accuracy: 0.216133
# Epoch 6_37.378%:  Training average Loss: 0.974085, Training accuracy: 0.222604
# Epoch 6_38.446%:  Training average Loss: 0.974063, Training accuracy: 0.228777
# Epoch 6_39.514%:  Training average Loss: 0.974120, Training accuracy: 0.235174
# Epoch 6_40.582%:  Training average Loss: 0.973887, Training accuracy: 0.241699
# Epoch 6_41.650%:  Training average Loss: 0.974460, Training accuracy: 0.247958
# Epoch 6_42.718%:  Training average Loss: 0.974535, Training accuracy: 0.254269
# Epoch 6_43.786%:  Training average Loss: 0.974201, Training accuracy: 0.260773
# Epoch 6_44.854%:  Training average Loss: 0.972943, Training accuracy: 0.267522
# Epoch 6_45.922%:  Training average Loss: 0.972799, Training accuracy: 0.273962
# Epoch 6_46.990%:  Training average Loss: 0.973613, Training accuracy: 0.280156
# Epoch 6_48.058%:  Training average Loss: 0.973716, Training accuracy: 0.286628
# Epoch 6_49.126%:  Training average Loss: 0.973419, Training accuracy: 0.293047
# Epoch 6_50.194%:  Training average Loss: 0.974620, Training accuracy: 0.299134
# Epoch 6_51.262%:  Training average Loss: 0.974879, Training accuracy: 0.305552
# Epoch 6_52.330%:  Training average Loss: 0.975623, Training accuracy: 0.311608
# Epoch 6_53.398%:  Training average Loss: 0.975139, Training accuracy: 0.317909
# Epoch 6_54.466%:  Training average Loss: 0.974739, Training accuracy: 0.324306
# Epoch 6_55.534%:  Training average Loss: 0.974581, Training accuracy: 0.330767
# Epoch 6_56.602%:  Training average Loss: 0.974211, Training accuracy: 0.337153
# Epoch 6_57.670%:  Training average Loss: 0.974536, Training accuracy: 0.343304
# Epoch 6_58.737%:  Training average Loss: 0.974262, Training accuracy: 0.349958
# Epoch 6_59.805%:  Training average Loss: 0.973877, Training accuracy: 0.356462
# Epoch 6_60.873%:  Training average Loss: 0.973582, Training accuracy: 0.362880
# Epoch 6_61.941%:  Training average Loss: 0.974028, Training accuracy: 0.369031
# Epoch 6_63.009%:  Training average Loss: 0.973811, Training accuracy: 0.375258
# Epoch 6_64.077%:  Training average Loss: 0.973448, Training accuracy: 0.381761
# Epoch 6_65.145%:  Training average Loss: 0.973812, Training accuracy: 0.388052
# Epoch 6_66.213%:  Training average Loss: 0.973640, Training accuracy: 0.394641
# Epoch 6_67.281%:  Training average Loss: 0.973416, Training accuracy: 0.400974
# Epoch 6_68.349%:  Training average Loss: 0.973444, Training accuracy: 0.407157
# Epoch 6_69.417%:  Training average Loss: 0.973032, Training accuracy: 0.413736
# Epoch 6_70.485%:  Training average Loss: 0.972826, Training accuracy: 0.420144
# Epoch 6_71.553%:  Training average Loss: 0.972773, Training accuracy: 0.426818
# Epoch 6_72.621%:  Training average Loss: 0.972600, Training accuracy: 0.433130
# Epoch 6_73.689%:  Training average Loss: 0.972401, Training accuracy: 0.439324
# Epoch 6_74.757%:  Training average Loss: 0.972535, Training accuracy: 0.445646
# Epoch 6_75.825%:  Training average Loss: 0.972973, Training accuracy: 0.451787
# Epoch 6_76.893%:  Training average Loss: 0.973040, Training accuracy: 0.458355
# Epoch 6_77.961%:  Training average Loss: 0.973108, Training accuracy: 0.464944
# Epoch 6_79.029%:  Training average Loss: 0.973166, Training accuracy: 0.471192
# Epoch 6_80.097%:  Training average Loss: 0.972882, Training accuracy: 0.477835
# Epoch 6_81.164%:  Training average Loss: 0.973192, Training accuracy: 0.484253
# Epoch 6_82.232%:  Training average Loss: 0.973279, Training accuracy: 0.490543
# Epoch 6_83.300%:  Training average Loss: 0.973407, Training accuracy: 0.497026
# Epoch 6_84.368%:  Training average Loss: 0.973377, Training accuracy: 0.503412
# Epoch 6_85.436%:  Training average Loss: 0.973338, Training accuracy: 0.509606
# Epoch 6_86.504%:  Training average Loss: 0.972658, Training accuracy: 0.516302
# Epoch 6_87.572%:  Training average Loss: 0.972416, Training accuracy: 0.522699
# Epoch 6_88.640%:  Training average Loss: 0.971997, Training accuracy: 0.529182
# Epoch 6_89.708%:  Training average Loss: 0.971881, Training accuracy: 0.535760
# Epoch 6_90.776%:  Training average Loss: 0.971838, Training accuracy: 0.541997
# Epoch 6_91.844%:  Training average Loss: 0.971826, Training accuracy: 0.548362
# Epoch 6_92.912%:  Training average Loss: 0.971766, Training accuracy: 0.554930
# Epoch 6_93.980%:  Training average Loss: 0.971979, Training accuracy: 0.561274
# Epoch 6_95.048%:  Training average Loss: 0.971949, Training accuracy: 0.567650
# Epoch 6_96.116%:  Training average Loss: 0.972043, Training accuracy: 0.574004
# Epoch 6_97.184%:  Training average Loss: 0.972063, Training accuracy: 0.580615
# Epoch 6_98.252%:  Training average Loss: 0.971804, Training accuracy: 0.587118
# Epoch 6_99.320%:  Training average Loss: 0.971363, Training accuracy: 0.593611
# Epoch 6 :  Verification average Loss: 0.970196, Verification accuracy: 19.989961%,Total Time:3217.037189
# Epoch 7_1.068%:  Training average Loss: 0.929424, Training accuracy: 0.006568
# Epoch 7_2.136%:  Training average Loss: 0.962692, Training accuracy: 0.012880
# Epoch 7_3.204%:  Training average Loss: 0.974907, Training accuracy: 0.018903
# Epoch 7_4.272%:  Training average Loss: 0.971091, Training accuracy: 0.025268
# Epoch 7_5.340%:  Training average Loss: 0.979517, Training accuracy: 0.031195
# Epoch 7_6.408%:  Training average Loss: 0.973822, Training accuracy: 0.037528
# Epoch 7_7.476%:  Training average Loss: 0.972218, Training accuracy: 0.044021
# Epoch 7_8.544%:  Training average Loss: 0.966377, Training accuracy: 0.050632
# Epoch 7_9.612%:  Training average Loss: 0.967072, Training accuracy: 0.057018
# Epoch 7_10.680%:  Training average Loss: 0.968077, Training accuracy: 0.063575
# Epoch 7_11.747%:  Training average Loss: 0.967804, Training accuracy: 0.069866
# Epoch 7_12.815%:  Training average Loss: 0.971526, Training accuracy: 0.076092
# Epoch 7_13.883%:  Training average Loss: 0.970408, Training accuracy: 0.082510
# Epoch 7_14.951%:  Training average Loss: 0.968320, Training accuracy: 0.089025
# Epoch 7_16.019%:  Training average Loss: 0.968140, Training accuracy: 0.095454
# Epoch 7_17.087%:  Training average Loss: 0.968834, Training accuracy: 0.101840
# Epoch 7_18.155%:  Training average Loss: 0.968130, Training accuracy: 0.108355
# Epoch 7_19.223%:  Training average Loss: 0.967071, Training accuracy: 0.114869
# Epoch 7_20.291%:  Training average Loss: 0.965910, Training accuracy: 0.121437
# Epoch 7_21.359%:  Training average Loss: 0.965660, Training accuracy: 0.127930
# Epoch 7_22.427%:  Training average Loss: 0.966710, Training accuracy: 0.134573
# Epoch 7_23.495%:  Training average Loss: 0.966038, Training accuracy: 0.140917
# Epoch 7_24.563%:  Training average Loss: 0.966554, Training accuracy: 0.147378
# Epoch 7_25.631%:  Training average Loss: 0.967056, Training accuracy: 0.153775
# Epoch 7_26.699%:  Training average Loss: 0.967690, Training accuracy: 0.160257
# Epoch 7_27.767%:  Training average Loss: 0.968198, Training accuracy: 0.166323
# Epoch 7_28.835%:  Training average Loss: 0.969628, Training accuracy: 0.172485
# Epoch 7_29.903%:  Training average Loss: 0.968494, Training accuracy: 0.179085
# Epoch 7_30.971%:  Training average Loss: 0.967408, Training accuracy: 0.185568
# Epoch 7_32.039%:  Training average Loss: 0.967332, Training accuracy: 0.192050
# Epoch 7_33.107%:  Training average Loss: 0.967184, Training accuracy: 0.198159
# Epoch 7_34.175%:  Training average Loss: 0.967453, Training accuracy: 0.204417
# Epoch 7_35.242%:  Training average Loss: 0.967466, Training accuracy: 0.210942
# Epoch 7_36.310%:  Training average Loss: 0.967234, Training accuracy: 0.217211
# Epoch 7_37.378%:  Training average Loss: 0.965962, Training accuracy: 0.223993
# Epoch 7_38.446%:  Training average Loss: 0.966819, Training accuracy: 0.230272
# Epoch 7_39.514%:  Training average Loss: 0.968059, Training accuracy: 0.236637
# Epoch 7_40.582%:  Training average Loss: 0.967591, Training accuracy: 0.243205
# Epoch 7_41.650%:  Training average Loss: 0.967454, Training accuracy: 0.249624
# Epoch 7_42.718%:  Training average Loss: 0.968084, Training accuracy: 0.255892
# Epoch 7_43.786%:  Training average Loss: 0.967919, Training accuracy: 0.262108
# Epoch 7_44.854%:  Training average Loss: 0.967028, Training accuracy: 0.268687
# Epoch 7_45.922%:  Training average Loss: 0.966635, Training accuracy: 0.275233
# Epoch 7_46.990%:  Training average Loss: 0.965483, Training accuracy: 0.281940
# Epoch 7_48.058%:  Training average Loss: 0.964871, Training accuracy: 0.288583
# Epoch 7_49.126%:  Training average Loss: 0.964367, Training accuracy: 0.295161
# Epoch 7_50.194%:  Training average Loss: 0.964459, Training accuracy: 0.301654
# Epoch 7_51.262%:  Training average Loss: 0.963373, Training accuracy: 0.308179
# Epoch 7_52.330%:  Training average Loss: 0.963052, Training accuracy: 0.314651
# Epoch 7_53.398%:  Training average Loss: 0.962892, Training accuracy: 0.321166
# Epoch 7_54.466%:  Training average Loss: 0.963060, Training accuracy: 0.327541
# Epoch 7_55.534%:  Training average Loss: 0.962947, Training accuracy: 0.334141
# Epoch 7_56.602%:  Training average Loss: 0.963855, Training accuracy: 0.340346
# Epoch 7_57.670%:  Training average Loss: 0.964700, Training accuracy: 0.346733
# Epoch 7_58.737%:  Training average Loss: 0.965325, Training accuracy: 0.353119
# Epoch 7_59.805%:  Training average Loss: 0.964835, Training accuracy: 0.359879
# Epoch 7_60.873%:  Training average Loss: 0.965304, Training accuracy: 0.366116
# Epoch 7_61.941%:  Training average Loss: 0.965421, Training accuracy: 0.372353
# Epoch 7_63.009%:  Training average Loss: 0.965060, Training accuracy: 0.378974
# Epoch 7_64.077%:  Training average Loss: 0.965522, Training accuracy: 0.385147
# Epoch 7_65.145%:  Training average Loss: 0.965660, Training accuracy: 0.391480
# Epoch 7_66.213%:  Training average Loss: 0.966069, Training accuracy: 0.397770
# Epoch 7_67.281%:  Training average Loss: 0.965925, Training accuracy: 0.404060
# Epoch 7_68.349%:  Training average Loss: 0.966252, Training accuracy: 0.410415
# Epoch 7_69.417%:  Training average Loss: 0.966053, Training accuracy: 0.417004
# Epoch 7_70.485%:  Training average Loss: 0.965284, Training accuracy: 0.423647
# Epoch 7_71.553%:  Training average Loss: 0.965339, Training accuracy: 0.430065
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-63d2267a9397> in <module>
#      23         total_loss = total_loss + loss.item()
#      24
# ---> 25         loss.backward()
#      26         optimizer.step()
#      27
#
# ~\.conda\envs\python36\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     105                 products. Defaults to ``False``.
#     106         """
# --> 107         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     108
#     109     def register_hook(self, hook):
#
# ~\.conda\envs\python36\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      91     Variable._execution_engine.run_backward(
#      92         tensors, grad_tensors, retain_graph, create_graph,
# ---> 93         allow_unreachable=True)  # allow_unreachable flag
#      94
#      95
#
# KeyboardInterrupt:

# %%
#测试
PATH='model_dict/model_lstm/epoch_5_accuracy_0.200765'
model = torch.load(PATH)

total_loss=0.0
accuracy=0.0
total_correct=0.0
total_data_num = len(train_iterator.dataset)
steps = 0.0    
start_time=time.time()
for batch in test_iterator:
    steps+=1
    batch_text=batch.Phrase
    batch_label=batch.Sentiment
    out=model(batch_text)
    loss = criterion(out, batch_label)
    total_loss = total_loss + loss.item()

    correct = (torch.max(out, dim=1)[1].view(batch_label.size()) == batch_label).sum()
    total_correct = total_correct + correct.item()

print("Test average Loss: %f, Test accuracy: %f，Total time: %f"
  %(total_loss/steps, total_correct/total_data_num,time.time()-start_time) )
# Out:
# Test average Loss: 0.958765, Test accuracy: 0.200936，Total time: 4.736815
